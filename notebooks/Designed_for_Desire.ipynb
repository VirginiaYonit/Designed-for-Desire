# %% [markdown]
# # Designed for Desire
#
# A Cultural and Data-Driven Journey Through Sex Toy Evolution
#
#
# # 1. Introduction – Method, Motivation and Scope
#
# This project began with a lived observation and a lifelong curiosity
# While working in the adult retail industry, I started noticing generational patterns in sex toy preferences.
# Younger women often chose toys designed for penetration, while older women consistently gravitated toward external stimulators.
# From these informal but recurring dynamics, two hypotheses emerged:
#
# 1. That women, regardless of sexual orientation, express a strong desire for penetrative pleasure;
#
# 2. That women's evolving needs and voices have played a central role in transforming the sex toy industry.
#
# To validate or challenge these ideas, I launched a research project that merges **technological methods (web scraping, data visualization, generative AI)** with a **cultural and historical lens**, rooted in a critical but non-academic approach. My goal was not just to gather data, but to create a **readable, traceable and SMART-based exploration** that could interest both recruiters and readers passionate about the intersection of sexuality, identity, and innovation.
#
#
# ## Specific
#
# This study focuses on the **evolution of sex toy trends over time and across regions**, highlighting how product categories, target groups, and aesthetics have changed. Central to the inquiry is the role women have played as both consumers and innovators, reshaping a market once built for and by men.
#
#
# ## Measurable
#
# The project includes:
#
# * An analysis of 3 major brands (Beate Uhse, CalExotics, Sh!), each with a legacy of female leadership and product design
#
# * Manual and automated data extraction (bestsellers, usage categories, price comparisons)
#
# * Inclusion of cultural studies and a 2,000-women survey led by a high-impact blogger
#
# * A complementary examination of newer phenomena like fantasy dildos (Bad Dragon), color symbolism, and cosmetic arousal creams
#
# Every product was evaluated for its usage (internal, external, couple) and classified by intended physical interaction (F, M, Couple), a choice made consciously, with awareness of its limitations.
#
#
# ## Achievable
#
# Technologies used include:
#
# * requests, BeautifulSoup, and Selenium for web scraping
#
# * pandas, matplotlib, wordcloud, and openpyxl for data manipulation and visualization
#
# * text-based pattern analysis and AI-generated profiling for product categorization
#
# Despite limited access to internal sales data or demographics, I gathered **public-facing and structured datasets** and turned them into analyzable insight.
#
#
# ## Relevant
#
# I chose this subject not out of trendiness, but personal belief. I see sex toys as a **powerful symbol of freedom**, bodily, psychological, and cultural. While I don't label myself as a feminist, I feel deep pride in women's achievements and concern for the ongoing inequalities we face. This project, in its own way, is my contribution to a larger shift in how sexuality, tech, and gender intersect today.
# This is not just a data project, it’s a reflection on autonomy, storytelling, and how design can shape desire.
#
#
# ## Time-bound
#
# The study spans from historical and legal milestones (including Etsy's 2024 policy change) to current market strategies.
#
# **To better understand this transformation, we begin with a brief cultural and legal history of sex toys.**

# %%
# from bs4 import BeautifulSoup
from IPython.display import Image, display

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

print("Libraries installed successfully!")
# Out:
# Libraries installed successfully!

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import requests
import time
import csv
import json  # so it can be read buy programms
from openpyxl import load_workbook

# %%
# Wikipedia URL
url = "https://en.wikipedia.org/wiki/Sex_toy"

# Send a GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extract all headings (h2) which are section titles
    titles = soup.find_all("h2")

    print("Wikipedia Section Titles:")
    for title in titles:
        print(title.text.strip())  # Strip removes extra spaces
else:
    print("Failed to retrieve the page")
# Out:
# Wikipedia Section Titles:
# Contents
# Types
# History
# In literature
# Health, safety, and privacy concerns
# Care
# Legal issues
# Industry
# In popular culture
# Research
# See also
# References
# Further reading
# External links

# %%
#First Web Scraping Task: Wikipedia
# Wikipedia URL
url = "https://en.wikipedia.org/wiki/Sex_toy"

# Send a GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract all <a> tags (links)
    links = soup.find_all("a", href=True)

    print("Wikipedia Links Found:\n")

    for link in links:
        href = link['href']
        # Only include internal Wikipedia links (skip external ones)
        if href.startswith("/wiki/"):
            print("https://en.wikipedia.org" + href)  # Convert to full URL

else:
    print("Failed to retrieve the page")
# Out:
# Wikipedia Links Found:
#
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Wikipedia:Contents
# https://en.wikipedia.org/wiki/Portal:Current_events
# https://en.wikipedia.org/wiki/Special:Random
# https://en.wikipedia.org/wiki/Wikipedia:About
# https://en.wikipedia.org/wiki/Help:Contents
# https://en.wikipedia.org/wiki/Help:Introduction
# https://en.wikipedia.org/wiki/Wikipedia:Community_portal
# https://en.wikipedia.org/wiki/Special:RecentChanges
# https://en.wikipedia.org/wiki/Wikipedia:File_upload_wizard
# https://en.wikipedia.org/wiki/Special:SpecialPages
# https://en.wikipedia.org/wiki/Main_Page
# https://en.wikipedia.org/wiki/Special:Search
# https://en.wikipedia.org/wiki/Help:Introduction
# https://en.wikipedia.org/wiki/Special:MyContributions
# https://en.wikipedia.org/wiki/Special:MyTalk
# https://en.wikipedia.org/wiki/Sex_toy
# https://en.wikipedia.org/wiki/Talk:Sex_toy
# https://en.wikipedia.org/wiki/Sex_toy
# https://en.wikipedia.org/wiki/Sex_toy
# ...

# %%
# PRECIOUS INFO:
# The non-plu-ultra- code for finding paragrahs in Wikipedia:
# Wikipedia URL
url = "https://en.wikipedia.org/wiki/Sex_toy"

# Send a GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract all <p> (paragraph) tags
    paragraphs = soup.find_all("p")

    print("Extracted Paragraphs:\n")

    # Print the first 3 paragraphs (adjustable)
    for i, p in enumerate(paragraphs[:3]):  # Change [:3] to get more paragraphs
        text = p.text.strip()
        if text:  # Only print non-empty paragraphs
            print(f"Paragraph {i+1}:\n{text}\n")

else:
    print("Failed to retrieve the page")
# Out:
# Extracted Paragraphs:
#
# Paragraph 2:
# A sex toy is an object or device that is primarily used to facilitate sexual pleasure, such as a dildo, artificial vagina or vibrator.  Many popular sex toys are designed to resemble human genitals, and may be vibrating or non-vibrating. The term sex toy can also include BDSM apparatus and sex furniture such as sex swings; however, it is not applied to items such as birth control, pornography, or condoms. Alternative terms for sex toy include adult toy and the dated euphemism marital aid. Marital aid also has a broader meaning and is applied to drugs and herbs marketed to enhance or prolong sex.
#
# Paragraph 3:
# Sex toys are most commonly sold at sex shops or online, but they may also be sold in a pharmacy or chemist store, a pornographic store, a head shop, or a department store. Sex toys are available in almost all countries for males and females.

# %%
# Function to fetch and parse the Wikipedia page
def get_soup(url):
    response = requests.get(url)
    if response.status_code == 200:
        return BeautifulSoup(response.text, 'html.parser')  # Return parsed HTML
    else:
        print("Failed to retrieve the page")
        return None

# Wikipedia URL
url = "https://en.wikipedia.org/wiki/Sex_toy"
soup = get_soup(url)

if soup:
    # Find all tables on the page
    tables = soup.find_all("table")

    print(f"Total tables found: {len(tables)}")

    # Improve Pandas display settings for readability
    pd.set_option("display.max_colwidth", None)  # Prevent text truncation
    pd.set_option("display.max_rows", 10)  # Show more rows but avoid overflow

    # Process each table
    for idx, table in enumerate(tables):
        rows = table.find_all("tr")

        # Extract headers if available
        headers = [th.text.strip().replace("\n", " ") for th in rows[0].find_all("th")] if rows else []

        # Extract data rows
        data = []
        for row in rows[1:]:  # Skip header row
            cells = row.find_all("td")
            clean_cells = [cell.text.strip().replace("\n", " ") for cell in cells]  # Clean newlines
            data.append(clean_cells)

        # Convert to DataFrame for readability
        df = pd.DataFrame(data, columns=headers if headers else None)

        # Display the table in Jupyter
        if not df.empty:
            print(f"\n--- Table {idx+1} ---")
            display(df)  # This will correctly show tables in Jupyter Notebook
        else:
            print(f"Table {idx+1} is empty or unstructured.")
# Out:
# Total tables found: 7
# Table 1 is empty or unstructured.
# Table 2 is empty or unstructured.
# Table 3 is empty or unstructured.
#
# --- Table 4 ---
#                                                                                                                                                                       vteMasturbation
# 0  Anal masturbation Autocunnilingus Autofellatio Erotic electrostimulation Fingering Jerking off/wanking Phone sex Prostate massage Teledildonics Erotic asphyxiation Orgasm control
# 1                                Anal beads Artificial vagina Fleshlight Ben Wa balls Dildo Double penetration dildo Sex doll Sex machine Magic Wand Sybian Venus 2000 Vibrator Sound
# 2                                                                                                                               Masturbate-a-thon National Masturbation Day Wank Week
# ...

# %% [markdown]
# N.B.: Nella pagina in questione non ci sono tabelle ma vtes.

# %%
# Manually select relevant Wikipedia links
selected_links = [
    "https://en.wikipedia.org/wiki/Sex_toy#History",
    "https://www.johncoulthart.com/feuilleton/2011/02/14/the-choise-of-valentines-or-the-merie-ballad-of-nash-his-dildo/",
    "http://news.bbc.co.uk/2/hi/uk_news/england/essex/8589766.stm",
    "https://www.huffingtonpost.co.uk/2014/02/10/history-female-sex-toys-dildos-rampant-rabbits_n_4760274.html",
    "https://web.archive.org/web/20110912201055/http://articles.timesofindia.indiatimes.com/2011-02-02/rajkot/28365014_1_toys-sushil-dalshaniya-inflatable-latex-dolls",
    "https://www.indiatoday.in/msn-it/m-leisure/story/sex-toys-survey-thatspeople-punjabi-women-condoms-lubricants-lifest-1028971-2017-08-10"
]  # 

# Function to scrape and extract content from selected pages
def scrape_wikipedia_page(url):
    soup = get_soup(url)
    if soup:
        print(f"\nExtracting data from: {url}")

        # Extract Title
        title = soup.find("h1").text.strip()

        # Extract First Paragraphs
        paragraphs = [p.text.strip() for p in soup.find_all("p")[:5] if p.text.strip()]

        # Extract Section Titles
        headings = [h2.text.strip() for h2 in soup.find_all("h2")]

        # Store Data in Dictionary
        return {"Title": title, "URL": url, "Headings": headings, "Paragraphs": paragraphs}
    return None

# Scrape all selected pages
scraped_data = [scrape_wikipedia_page(url) for url in selected_links]

# Convert to DataFrame for structured viewing
df_scraped = pd.DataFrame(scraped_data)

# Display extracted data
print("\n--- Scraped Wikipedia Pages ---")
display(df_scraped)
# Out:
# Extracting data from: https://en.wikipedia.org/wiki/Sex_toy#History
#
# Extracting data from: https://www.johncoulthart.com/feuilleton/2011/02/14/the-choise-of-valentines-or-the-merie-ballad-of-nash-his-dildo/
#
# Extracting data from: http://news.bbc.co.uk/2/hi/uk_news/england/essex/8589766.stm
#
# Extracting data from: https://www.huffingtonpost.co.uk/2014/02/10/history-female-sex-toys-dildos-rampant-rabbits_n_4760274.html
#
# Extracting data from: https://web.archive.org/web/20110912201055/http://articles.timesofindia.indiatimes.com/2011-02-02/rajkot/28365014_1_toys-sushil-dalshaniya-inflatable-latex-dolls
#
# Extracting data from: https://www.indiatoday.in/msn-it/m-leisure/story/sex-toys-survey-thatspeople-punjabi-women-condoms-lubricants-lifest-1028971-2017-08-10
#
# --- Scraped Wikipedia Pages ---
#                                                                   Title  \
# 0                                                               Sex toy
# ...

# %%
# 1. Find the "History" heading (<h2>)
# 2. Extract all paragraphs (<p>) after it

for tag in soup.find_all(["h1", "h2", "p", "div"]):
    if tag.name in ["h1", "h2"]:  # Print section titles
        print(f"\n🔹 Section: {tag.text.strip()}  ({tag.name})")
    elif tag.name == "p":  # Print a sample of paragraphs
        print(f"  - Paragraph: {tag.text.strip()[:150]}...")
    elif tag.name == "div":  # Show container divs to see structure
        print(f"  🏗️ Container: <div> found with class {tag.get('class')}")
# Out:
#   🏗️ Container: <div> found with class ['vector-header-container']
#   🏗️ Container: <div> found with class ['vector-header-start']
#   🏗️ Container: <div> found with class ['vector-dropdown', 'vector-main-menu-dropdown', 'vector-button-flush-left', 'vector-button-flush-right']
#   🏗️ Container: <div> found with class ['vector-dropdown-content']
#   🏗️ Container: <div> found with class ['vector-unpinned-container']
#   🏗️ Container: <div> found with class ['vector-main-menu', 'vector-pinnable-element']
#   🏗️ Container: <div> found with class ['vector-pinnable-header', 'vector-main-menu-pinnable-header', 'vector-pinnable-header-unpinned']
#   🏗️ Container: <div> found with class ['vector-pinnable-header-label']
#   🏗️ Container: <div> found with class ['vector-menu', 'mw-portlet', 'mw-portlet-navigation']
#   🏗️ Container: <div> found with class ['vector-menu-heading']
#   🏗️ Container: <div> found with class ['vector-menu-content']
# ...

# %%
# The next code was a master research done with ChatGPT. Wikipidia didn't wan't to let me access
# the History's paragraph. 
# KEEP IT PRECIOUS dr. Watson!

# Why This Fix Works:
# Scans ALL paragraphs on the page → No more guessing Wikipedia’s structure.
# Tracks which section each paragraph belongs to dynamically.
# Extracts only paragraphs that belong to "History."
# Function to fetch and parse the Wikipedia page

def get_soup(url):
    response = requests.get(url)
    if response.status_code == 200:
        return BeautifulSoup(response.text, 'html.parser')  # Return parsed HTML
    else:
        print(f"Failed to retrieve the page: {url}")
        return None

# Wikipedia URL
url = "https://en.wikipedia.org/wiki/Sex_toy"
soup = get_soup(url)

if soup:
    history_paragraphs = []
    current_section = None

    # Find all elements that could be headings or paragraphs
    for tag in soup.find_all(["h2", "p"]):
        if tag.name == "h2":  # If it's a section heading, update current_section
            current_section = tag.text.strip().replace("[edit]", "").strip().lower()
        elif tag.name == "p" and current_section == "history":  # If it's a <p> inside "History"
            history_paragraphs.append(tag.text.strip())

    # Print extracted paragraphs
    if history_paragraphs:
        print("\n--- Extracted History Section ---\n")
        for idx, para in enumerate(history_paragraphs, start=1):
            print(f"Paragraph {idx}: {para}\n")
    else:
        print("Still no content found under 'History' (even after scanning all paragraphs).")
# Out:
# --- Extracted History Section ---
#
# Paragraph 1: Dildos in one form or another have existed widely in history. Artifacts from the Upper Paleolithic of a type called bâton de commandement have been speculated to have been used for sexual purposes.[17]  Few archaeologists consider these items as sex toys, but archaeologist Timothy Taylor put it, "Looking at the size, shape, and—some cases—explicit symbolism of the ice age batons, it seems disingenuous to avoid the most obvious and straightforward interpretation. But it has been avoided."[18][19]
#
# ...

# %%
# Find any element containing "Legal issues" and print nearby content
target_section = "Legal issues"  # Instead of "History"

legal_issues_elements = soup.find_all(string=lambda text: text and "legal issues" in text.lower())

if legal_issues_elements:
    print("\n--- Debugging: Where Is 'Legal Issues' on the Page? ---\n")

    for element in legal_issues_elements:
        parent = element.find_parent()  # Find the closest parent container
        print(f"\n🔹 Found in: <{parent.name}> with attributes: {parent.attrs}\n")
        print(parent.prettify()[:500])  # Print the first 500 characters for context
else:
    print(" 'Legal Issues' was not found anywhere in the page content!")
# Out:
# --- Debugging: Where Is 'Legal Issues' on the Page? ---
#
#
# 🔹 Found in: <span> with attributes: {}
#
# <span>
#  Legal issues
# </span>
#
#
# 🔹 Found in: <span> with attributes: {}
#
# <span>
#  Toggle Legal issues subsection
# </span>
#
#
# 🔹 Found in: <h2> with attributes: {'id': 'Legal_issues'}
#
# <h2 id="Legal_issues">
#  Legal issues
# </h2>

# %% [markdown]
# ... Is it a joke??? No parahraphs??? In any case, we'll crack it!

# %%
# Search for any paragraph that mentions "Legal issues"
legal_paragraphs = []

for p in soup.find_all("p"):
    if "legal" in p.text.lower() or "law" in p.text.lower() or "regulation" in p.text.lower():
        legal_paragraphs.append(p.text.strip())

# Print extracted legal content
if legal_paragraphs:
    print("\n--- Extracted Legal Issues Section ---\n")
    for idx, para in enumerate(legal_paragraphs, start=1):
        print(f"Paragraph {idx}: {para}\n")
else:
    print("No legal-related paragraphs found anywhere on the page!")
# Out:
# --- Extracted Legal Issues Section ---
#
# Paragraph 1: Standards set for sex toys are set in ISO 3533:2021. The sex toys are sold as novelty items so they do not need to adhere to certain regulations such as reporting the chemicals and materials used in a product. Due to this status, manufacturers are not responsible if their toys are used for any other purpose than being a novelty.[50] Regulations such as REACH[51] do exist, and some sex toys may be compliant to this though, despite that there is no obligation for manufacturers on attaining compliance.  A 2006 study conducted by the Greenpeace Netherlands office found high level of phthalates in seven out of eight plastic sex toys tested.[52] Phthalates are chemical plasticizers that are added as softeners, to create the malleable and soft effect that many look for in sex toys.[53]
#
# ...

# %%
# Step 1: confirm we have the data
print("Title of sections:")
print(titles[:5])  # Print the first 5 titles
print("\nExtracted links:")
print(links[:5])  # Print the first 5 links

print("\nExtracted paragraphs:")
print(legal_paragraphs[:2])  # Print the first 3 paraghraps for verification
# Out:
# Title of sections:
# [<h2 class="vector-pinnable-header-label">Contents</h2>, <h2 id="Types">Types</h2>, <h2 id="History">History</h2>, <h2 id="In_literature">In literature</h2>, <h2 id="Health,_safety,_and_privacy_concerns"><span id="Health.2C_safety.2C_and_privacy_concerns"></span>Health, safety, and privacy concerns</h2>]
#
# Extracted links:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>, <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>, <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>, <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>, <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>]
#
# Extracted paragraphs:
# ...

# %%
# Step 2: Define the function to save the text
def save_to_txt(titles, links, legal_paragraphs, filename="scraped_data.txt"):
    with open(filename, "w", encoding="utf-8") as file:
        file.write("=== SECTION'S TITLES ===\n")
        for title in titles:
            file.write(f"- {title}\n")
        
        file.write("\n=== PRESENT LINKS ===\n")
        for link in links:
            file.write(f"- {link}\n")
        
        file.write("\n=== EXTRACTED PARAGRAPHS ===\n")
        for i, paragraph in enumerate(legal_paragraphs, 1):
            file.write(f"\nParagraph {i}:\n{paragraph}\n")
    
    print(f"Data saved in {filename}")

# %%
# Step 3: Save the file TXT to generate the .txt file:
save_to_txt(titles, links, legal_paragraphs)
# Out:
# Data saved in scraped_data.txt

# %%
# Step 4: Verify if the file has been created and safely saved
with open("scraped_data.txt", "r", encoding="utf-8") as file:
    content = file.read()

# Print the first 50 rows (avoid confusion!)
print("\n".join(content.split("\n")[:50]))
# Out:
# === SECTION'S TITLES ===
# - <h2 class="vector-pinnable-header-label">Contents</h2>
# - <h2 id="Types">Types</h2>
# - <h2 id="History">History</h2>
# - <h2 id="In_literature">In literature</h2>
# - <h2 id="Health,_safety,_and_privacy_concerns"><span id="Health.2C_safety.2C_and_privacy_concerns"></span>Health, safety, and privacy concerns</h2>
# - <h2 id="Care">Care</h2>
# - <h2 id="Legal_issues">Legal issues</h2>
# - <h2 id="Industry">Industry</h2>
# - <h2 id="In_popular_culture">In popular culture</h2>
# - <h2 id="Research">Research</h2>
# - <h2 id="See_also">See also</h2>
# - <h2 id="References">References</h2>
# - <h2 id="Further_reading">Further reading</h2>
# - <h2 id="External_links">External links</h2>
#
# === PRESENT LINKS ===
# - <a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# - <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>
# ...

# %%
# Define the function to save the CSV

def save_to_csv(headings, links, legal_paragraphs, filename="scraped_data.csv"):
    # Troviamo la lunghezza massima per evitare errori
    max_length = max(len(headings), len(links), len(legal_paragraphs))

    # Fill up the shorter lists with empty strings to make neat
    headings += [""] * (max_length - len(titles))
    links += [""] * (max_length - len(links))
    legal_paragraphs += [""] * (max_length - len(legal_paragraphs))

    # Create the df
    data = {
        "Titles": headings,
        "Links": links,
        "Paragrphs": legal_paragraphs
    }
    
    df = pd.DataFrame(data)
    df.to_csv(filename, index=False, encoding="utf-8")

    print(f"Data saved in {filename}")

# %%
# Create the .CSV file
save_to_csv(titles, links, legal_paragraphs)
# Out:
# Data saved in scraped_data.csv

# %%
# Read the file
df = pd.read_csv("scraped_data.csv")

# %%
# Wikipedia URL
url = "https://en.wikipedia.org/wiki/Sex_toy"

# Call the page and create the object BeautifulSoup
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Extract titles 
headings = [h.get_text(strip=True) for h in soup.find_all(['h1', 'h2', 'h3'])]

# Print to verify
print("Headings extracted (first 5 voices):", headings[:5])
# Out:
# Headings extracted (first 5 voices): ['Contents', 'Sex toy', 'Types', 'Erotic electrostimulation', 'Erotic furniture']

# %%
links = soup.find_all('a')
paragraphs = soup.find_all('p')

# Defining a funtion to clean it
def clean_data(headings, links, paragraphs):
    # remouve none, Ellipsis and convert everything in strings
    headings = [str(h).strip() if h and h is not ... else "" for h in headings]
    links = [str(l.get('href')).strip() if hasattr(l, 'get') and l.get('href') else "" for l in links]
    paragraphs = [p.get_text(strip=True) if hasattr(p, 'get_text') else str(p).strip() for p in paragraphs]
    
    return headings, links, paragraphs

# Cleaning the data
headings, links, paragraphs = clean_data(headings, links, paragraphs)

# Stampiamo un'anteprima per verificare
print("Headings clean (first 5 voices):", headings[:5])
print("Link clean (first 5 voices):", links[:5])
print("Paragraphs clean (first 2 voices):", paragraphs[:2])
# Out:
# Headings clean (first 5 voices): ['Contents', 'Sex toy', 'Types', 'Erotic electrostimulation', 'Erotic furniture']
# Link clean (first 5 voices): ['#bodyContent', '/wiki/Main_Page', '/wiki/Wikipedia:Contents', '/wiki/Portal:Current_events', '/wiki/Special:Random']
# Paragraphs clean (first 2 voices): ['', 'Asex toyis an object or device that is primarily used to facilitatesexual pleasure, such as adildo,artificial vaginaorvibrator.  Many popular sex toys are designed to resemble human genitals, and may be vibrating or non-vibrating. The termsex toycan also includeBDSMapparatus andsex furnituresuch assex swings; however, it is not applied to items such asbirth control,pornography, orcondoms. Alternative terms forsex toyincludeadult toyand the dated euphemismmarital aid.Marital aidalso has a broader meaning and is applied todrugs and herbs marketed to enhance or prolong sex.']

# %%
# Define the function and save the json file
def save_to_json(headings, links, paragraphs, filename="scraped_data.json"):
    data = {
        "Headings": headings,
        "Links": links,
        "Paragrafi": paragraphs
    }
    
    with open(filename, "w", encoding="utf-8") as file:
        json.dump(data, file, indent=4, ensure_ascii=False)

    print(f"Data saved in {filename}")

save_to_json(headings, links, paragraphs)
# Out:
# Data saved in scraped_data.json

# %%
# Reading the file
with open("scraped_data.json", "r", encoding="utf-8") as file:
    data = json.load(file)

print(json.dumps(data, indent=4, ensure_ascii=False)[:1000])  # just first 1000 characters to avoid filling up the screen
# Out:
# {
#     "Headings": [
#         "Contents",
#         "Sex toy",
#         "Types",
#         "Erotic electrostimulation",
#         "Erotic furniture",
#         "General penetrative toys",
#         "Nipple toys",
#         "Penile toys",
#         "Vulvar toys",
#         "History",
#         "Dildos",
#         "Vibrators",
#         "In literature",
#         "Talmud",
#         "Early modern period",
#         "Health, safety, and privacy concerns",
#         "Care",
#         "Legal issues",
#         "India",
#         "Japan",
#         "Malaysia",
#         "South Africa",
#         "United States",
#         "Zimbabwe",
#         "Industry",
#         "In popular culture",
#         "Research",
#         "Positive and negative effects of sex toy use",
#         "See also",
#         "References",
#         "Further reading",
#         "External links"
#     ],
#     "Links": [
#         "#bodyContent",
#         "/wiki/Main_Page",
#         "/wiki/Wikipedia:Contents",
# ...

# %% [markdown]
# # 2 Historical & Cultural Background
#
# To grasp how sex toys have evolved into tools of empowerment and design, we must first understand their long and complex cultural lineage. This section presents a brief overview of the historical and cultural context surrounding sex toys, with a focus on the origins, meanings, and uses of the **dildo**, one of the oldest known sexual devices. Content is drawn primarily from the Wikipedia article on Sex toy (particularly the History section), complemented by other historical and etymological sources.
#
# The **etymology** of the word *dildo* has long been debated. According to the third edition of the Oxford English Dictionary (2018), the term likely derives from **nonsense syllables** used in early modern English ballads — not unlike the whimsical phrasing in "hey diddle diddle." These playful sounds served as euphemisms for sexual themes. One such ballad, *The Maid’s Complaint for Want of a Dil Doul*, uses “Dil Doul” to refer to a man’s penis and dates back to the 17th century. The song was cataloged in the private library of **Samuel Pepys**, a 17th-century English diarist and collector of popular ballads.
#
#
# **Key Terms Used in This Study**
#
# |Term	    | Definition                                                                                    |
# |-----------|-----------------------------------------------------------------------------------------------|
# |Dildo      | A non-vibrating object designed for penetration. Often phallic, made of silicone, rubber, glass, etc. Does not contain electronic components.|
# |Vibrator   | A toy with a motor that produces vibrations to stimulate erogenous zones. Can be internal, external, or hybrid; varies widely in shape and function.|
# |Masturbator | Typically penis-focused, such as sleeves or strokers. Broader use includes any solo-use device for genital stimulation.|
# |Sex Toy    | An umbrella term for all objects enhancing sexual pleasure: dildos, vibrators, plugs, masturbators, BDSM items, etc.|
#
# These definitions reflect the language used in contemporary product descriptions and market analysis.
#
# ## 2.1 Timeline of Sex Toys: Historical and Legal Milestones
#
# The timeline below highlights key milestones in the material and cultural history of sex toys. From early symbolic artefacts to modern innovations, these moments reflect how pleasure, gender, and taboo have been negotiated across time and cultures.
#
# | Period              | Event / Artefact Description                                                                 | Location               | Notes                                                               |
# |---------------------|-----------------------------------------------------------------------------------------------|------------------------|---------------------------------------------------------------------|
# | ~30,000 BCE         | Bâton de commandement, possibly used as sex toy (phallic-shaped artefacts)                    | Europe (Paleolithic)   | Considered symbolic, debated use                                    |
# | ~13,000–19,000 BCE  | Double-ended dildos, early penetration tools                                                  | Various                | Rare archaeological finds                                           |
# | ~3000 BCE           | Erotic depictions with dildos in wall paintings                                               | Ancient Egypt          | Used in varied contexts                                             |
# | ~2000 BCE           | Bronze phalluses found on a tomb                                                              | China                  | Symbols of pleasure and status                                      |
# | ~2000 BCE           | 16 cm wooden phallus, originally misclassified as a darning tool                              | Roman era              | Shows signs of wear, suggesting repeated use                        |
# | Pre–5th century BC  | Breadstick-shaped dildos ("olisbokollikes"); leather dildos stuffed with wool, oiled         | Ancient Greece         | Some pottery depicts solo or group use                              |
# | Medieval times      | Plants like the "Cantonese groin" used to fashion enlarged, usable dildos                    | Europe                 | Often referenced in erotic texts                                    |
# | 15th century        | Leather, wood, and stone dildos                                                               | Italy                  | Used for solo or partnered play                                     |
# | 15th century        | Lacquered wooden dildos sometimes buried with women                                           | China                  | Suggests symbolic value and ownership                               |
# | 1590s               | First literary mention of a glass dildo (*The Choise of Valentines*)                          | England                | Poem by Thomas Nashe                                                |
# | 17th–18th century   | Erotic shunga art shows women purchasing dildos                                               | Japan                  | Made of buffalo horn; openly depicted                               |
# | 18th century        | Pair of French wooden dildos ("Travel Godermiche") created                                    | France                 | Stored in a leather-lined case                                      |
# | Late 19th century   | Wooden dildos (single and double-ended) documented in ethnographic research                   | Zanzibar               | Illustrated by Haberlandt                                           |
# | Late 1880s          | Electromechanical vibrators invented by Joseph Mortimer Granville                            | England                | Originally for medical use                                          |
# | 1947                | Beate Uhse publishes *Schrift X*, a contraceptive information magazine                        | West Germany           | Promoted Ogino-Knaus method                                         |
# | 1962                | Beate Uhse opens the world’s first sex shop                                                   | Germany                | Pioneering move toward retail normalization                         |
# | Late 1960s          | Hitachi launches the Magic Wand                                                               | Japan                  | Marketed for muscle pain; adopted for sexual use                    |
# | Late 1960s          | Feminist Betty Dodson leads masturbation workshops using the Magic Wand                      | New York City          | Milestone for sex-positive feminism                                 |
# | 1992                | Sh! is founded by Kathryn Hoyle and Sophie Walters                                            | London                 | Men allowed only when accompanied; cultural shift in retail         |
# | 1994                | Susan Colvin founds CalExotics, first woman-owned sex toy company                             | USA                    | Focus on color, waterproof design, and quality silicone             |
# | 2002                | A new era of adult online toy shopping begins: Lovehoney is born 	                                                                              | England                    | Sexual happiness, mainstream appeal|
# | 2008                | Bad Dragon is founded                                                                         | USA                    | Fantasy-themed, customizable toys; strong online community          |
# | 2010                | Auction of 18th-century wooden dildos for £3,600                                              | Essex, UK              | Brought historical artefacts into public view                       |
# | 2016                | Internet-connected sex toys shown vulnerable to cyberattacks                                  | Italy                  | Exposed by Trend Micro; raised privacy and security concerns        |
#
#
#
# ## 2.2 Notable Historical Artefacts – Visual History of Pleasure
#
# Phallic objects have been found in many ancient cultures across the globe, serving as ritual symbols, fertility charms, or perhaps simply as intimate tools. While historical interpretations are often tentative, the physical traces left behind offer a compelling visual history of human sexuality, and its material imagination.
#
# ###  2.2.1 Visual Appendix: Selected Artefacts
#
# Alongside textual and archaeological traces, visual artefacts provide powerful evidence of historical engagement with pleasure.
#
# <table>
#   <tr>
#     <td>
#       <img src="images/24AB6B4300000578-2908415-A_7_8_inch_20cm_long_1_1_inch_3cm_wide_stone_object_pictured_was-a-31_1421165230066.jpg" width="220"><br>
#       <sub><b>Germany, 28,000 BCE</b><br>
#       A carved siltstone object found in Hohle Fels Cave, interpreted by archaeologists as one of the oldest known dildos.</sub>
#     </td>
#     <td>
#       <img src="images/2-000-year-old-artifacts-found-in-tombs-of-ancient-chinese-v0-izjvxx47ylwc1.jpeg" alt="ronze and jade phallic objects discovered in elite tombs. Their exact function remains debated, but theories range from symbolic guardians to sexual implements."width="220"><br>
#       <sub><b>China, Han Dynasty (c. 200 BCE)</b><br>
#       Bronze and jade phallic objects discovered in elite tombs. Their exact function remains debated, but theories range from symbolic guardians to sexual implements.</sub>
#     </td>
#     <td>
#       <img src="images/The-Vindolanda-wooden-phallus.jpg" alt='A wooden 2-000-year phallus, discovered near Hadrian's Wall, may have served as a symbolic offering, a torture instrument, or a practical object.' width="220"><br>
#       <sub><b>Roman Britain (Vindolanda Fort)</b><br>
#       This wooden phallus, discovered near Hadrian's Wall, may have served as a symbolic offering, a torture instrument, or a practical object.</sub>
#     </td>
#   </tr>
# </table>
#
# ---
#
# ###  2.2.2 “Travel Godermiche”: A Collector's Treasure
#
# In 2010, a remarkable pair of 18th-century sex toys, likely French, was sold at Brentwood Antiques Auction in Essex, UK, for £3,600.
#
# The items, carved from wood and stored in a fitted, leather-lined case adorned with fleurs-de-lys, were listed under the rare title "*Travel Godermiche*", a historic term used to describe phallic instruments.
#
# > “You might laugh but it's a good opportunity for investment. You won't see another one in a long time.”
# > — *Wendy Wood, Auctioneer*
#
# Described as *extraordinary and exceptionally rare*, these objects hold significance not only as curiosities but as cultural artefacts—testimonies to centuries of discreet pleasure.
#
# 🔗 Source: [BBC News – Historic sex toys sold for £3,600 at Essex auction](http://news.bbc.co.uk/2/hi/uk_news/england/essex/8589766.stm)
#
# <table>
#   <tr>
#     <td>
#       <img src="images/Essex_auction.jpg" alt='Pair of 18th-century wooden sex toys auctioned in Essex.' width="350"><br>
#       <sub><b>Figure 1 – Pair of 18th-century wooden sex toys auctioned in Essex.</b><br>
#       The fitted case and craftsmanship reflect the artisanal and symbolic value of such historical erotic objects.</sub>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# ## 2.3 Timeline: Legal and Cultural Milestones
#
# The legal history surrounding sex toys reflects broader societal attitudes toward sexuality, morality, and gender.
#
# | Period            | Legal Event or Change                                                                                                                   | Location         | Notes                                    |
# |------------------|-----------------------------------------------------------------------------------------------------------------------------------------|------------------|------------------------------------------|
# | 1957              | Sexual Offenses Act prohibits sale/import of sex toys                                                         | Malaysia         | Ban in place                            |
# | 1969              | Immorality Amendment Act bans manufacture and sale of sex toys (aimed at lesbians)                           | South Africa     | Later repealed in 2007                  |
# | 1975              | Legalization of pornography, facilitating sexual culture expansion                                            | West Germany     | Context for Beate Uhse's business boom  |
# | 1996   | Breast Cancer Charity refuses money raised through catalogue sales from Sh! | England   | "A SEX SHOP!'  '...no, sorry, we can't accept it'. Luckly, specially for cancer's patients, Breakthrough Breast Cancer thinks in a different way
# | 2007              | Alabama law upholding sex toy ban confirmed; considered no "fundamental right to orgasm devices"             | Alabama, USA     | Strict restriction maintained           |
# | 2007              | South Africa repeals ban on sex toys with Criminal Law (Sexual Offences and Related Matters) Amendment Act   | South Africa     | Legalization                            |
# | 2008              | Texas ban on sex toys overturned as unconstitutional (14th Amendment, privacy rights)                        | Texas, USA       | Legalization through courts             |
# | Present           | Sale/possession of sex toys criminalized as "obscene" under Section 292                                       | India            | Ban in force                            |
# | Present           | Sex toys in Japan designed to look like animals or cartoons to bypass obscenity laws                         | Japan            | Legal through indirect means            |
# | Present           | Import/possession of sex toys considered obscene and fined or punished with prison                           | Zimbabwe         | Active strict ban                       |
# July 2024| [Etsy ban the sale of sex toys as well as “printed or visual materials” that exist for “the purpose of sexual arousal or stimulation”](https://www.theguardian.com/business/article/2024/jul/11/etsy-sellers-ban-sex-toys-betrayal) | England  | The ban includs old Playboy issues and vintage adult magazines, and anything printed with sexual slogans related to “daddy” or “mommy” |

# %% [markdown]
# The legal history surrounding sex toys reflects broader societal attitudes toward sexuality, morality, and gender.
#
# In 1957, Malaysia introduced explicit bans on the sale and import of sex toys, framing them as threats to public morality. Similar prohibitions appeared in South Africa in 1969, primarily targeting lesbian sexuality, and in several U.S. Southern states throughout the late 20th century. However, a notable cultural shift began in Europe.
#
# In 1975, West Germany legalized pornography, fostering a new era of open erotic commerce and supporting pioneers such as Beate Uhse. This change marked the beginning of broader normalization of sexual expression in Western Europe.
#
# In the early 2000s, the legal landscape in the United States also began to change: while Alabama reaffirmed its sex toy ban in 2007, Texas overturned its ban in 2008, citing constitutional privacy rights. Today, while countries like India and Zimbabwe still criminalize sex toy possession, others have embraced legal and cultural acceptance, often navigating restrictions creatively — as seen in Japan’s design adaptations to circumvent obscenity laws.
#
# These developments illustrate how the acceptance of sex toys follows larger trends of liberalization, resistance, and cultural negotiation — but they also remind us that objects themselves are never neutral.
#
# While the phallic form has been historically central, its meaning varies greatly across time and context — from ritual object, to pornographic replica, to empowering tool of self-defined pleasure. The dildo, rather than being strictly patriarchal or feminist, is a contested symbol shaped by its cultural moment.
#
#
# <table>
#   <tr>
#     <td>
#       <img src="images/Pittore_dell'angelo_volante_(attr.),_anfora_con_falli-uccello_e_ragazza_con_un_fallo,_490_ac._ca._04.JPG" alt= 'Pottery art depicting a young man using a dildo' width="220"><br>
#       <sub><b>Ancient Greece</b><br>
#       Pottery art
#       </sub>
#     </td>
#     <td>
#       <img src="images/Lithograph-from-De-Figuris-Veneris(1906)by-Édouard-Henri Avril.jpg" alt= 'A lithograph from De Figuris Veneris (1906) by Édouard-Henri Avril showing a strap-on dildo being used by two women.' width="220"><br>
#       <sub><b>A strap-on dildo being used by two women.</b><br>
#        Lithograph from De Figuris Veneris (1906) by Édouard-Henri Avril</sub>
#     </td>
#     </tr>
# </table>
#
# For example, in 15th-century China, some women were reportedly buried with intricately crafted wooden dildos. This suggests that sex toys held symbolic value beyond functional pleasure. They may have represented a part of the self, personal identity, or even spiritual autonomy — a form of erotic continuity beyond life. Rather than reinforcing male-dominated narratives, such artefacts can point to private domains of agency, often overlooked in broader historical accounts.
#
# This duality invites us to rethink simplistic interpretations: the sex toy is not a passive object but an evolving cultural artifact, simultaneously shaped by and shaping ideas of gender, sexuality, and power.

# %% [markdown]
# # 3 Quantitative Insights: Beate Uhse
#
# **Beate Uhse**, one of the oldest and most iconic names in the European erotic market, offers a unique lens into consumer behavior. With a catalog that blends affordability, tradition, and accessibility, its product range provides valuable insight into popular preferences and evolving desires.
#
# In this section, we explore the company’s top-selling and most-loved vibrators, analyzing their characteristics through coded dimensions such as usage, target, materials, price range, and technical features. The goal is to highlight purchasing patterns and emotional resonance in the context of broader market trends.
#
# All product visualizations use a shared code system:
#
# **Legend**
# - F: Feminine
# - M: Masculine
# - C: Couple
# - Int: Internal
# - Ext: External
# - Sizes: S, S+, L, XL
# - Materials: Silicone, ABS, TPR, etc.
#
#
# ## 3.1 Methodological Approach: Exploring What Sells vs. What’s Loved
#
# To understand what drives consumer behavior, this section contrasts two curated product groups: Beate Uhse’s **bestsellers**, representing items most frequently purchased, and its **most loved vibrators**, highlighting user-rated favorites.
#
# While the former reflects trends driven by accessibility, price, or mass appeal, the latter offers insight into longer-term satisfaction, quality preferences, and emotional connection.
#
# The decision to focus specifically on **vibrators**, rather than dildos, stems from observed product availability: **dildos were notably absent from Beate Uhse’s bestsellers** list. This aligns with findings from the study Global Web Trends Analysis of Sex Toys by Müslim Doğan Değer and Burak Akgul, published in Sexual Medicine, which analyzed Google Trends data from 2009 to 2023. The study revealed a **sustained rise in interest for vibrators and masturbators**, alongside a **decline in interest for dildos since around 2016**.
# >While the study used search behavior as its metric, our analysis draws directly from Beate Uhse's online offerings, providing a complementary, product-based view.
#
# By comparing these product through visualizations sets across key variables (use, target, materials, price, and charging method) we aim to uncover patterns that explain not just what sells, but what resonates.

# %%
# We are going to find Beate Uhse's bestsellers
# 2. We are going to use chromedriver (that has been downloaded on my pc)
service = Service(executable_path="chromedriver.exe")  # <-- qui il percorso corretto
driver = webdriver.Chrome(service=service)

# 3. Apriamo la pagina
url = "https://www.beate-uhse.com/bestsellers?Kategorie=Sexspielzeug"
driver.get(url)

# 4. Aspettiamo che la pagina si carichi
time.sleep(5)

# 5. Prendiamo l'HTML della pagina
html = driver.page_source

# 6. Analizziamo con BeautifulSoup
soup = BeautifulSoup(html, "html.parser")

# 7. Troviamo i nomi dei prodotti
product_titles = soup.find_all("a", class_="edc-product-block__title")

# 8. Creiamo una lista dei nomi dei prodotti
products = [product.text.strip() for product in product_titles]

# 9. Salviamo i dati in un file CSV
with open('bestsellers.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Product Name'])  # column's name
    for name in products:
        writer.writerow([name])

# 10. Chiudiamo il browser
driver.quit()

print("'bestsellers.csv' succesfuly created!")
# Out:
# 'bestsellers.csv' succesfuly created!

# %%
# 1. Importiamo i moduli
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import csv

# 2. Impostiamo il driver
service = Service(executable_path="chromedriver.exe")  # <-- sostituire con percorso corretto
driver = webdriver.Chrome(service=service)

# 3. Apriamo la pagina
url = "https://www.beate-uhse.com/bestsellers?Kategorie=Sexspielzeug"
driver.get(url)

# 4. Aspettiamo il caricamento
time.sleep(5)

# 5. Prendiamo l'HTML
html = driver.page_source

# 6. Usiamo BeautifulSoup
soup = BeautifulSoup(html, "html.parser")

# 7. Troviamo tutti i prodotti
products = soup.find_all("article", class_="edc-product-block")

# 8. Estraiamo nome e prezzo
data = []
for product in products:
    # Troviamo il nome
    name_tag = product.find("a", class_="edc-product-block__title")
    name = name_tag.text.strip() if name_tag else "N/A"
    
    # Troviamo il prezzo
    price_tag = product.find("div", class_="edc-product-block__price-wrapper")
    price = price_tag.text.strip() if price_tag else "N/A"
    
    # Aggiungiamo alla lista
    data.append([name, price])

# 9. Salviamo su CSV
with open('bestsellers_with_prices.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Product Name', 'Price'])  # intestazioni colonne
    writer.writerows(data)

# 10. Chiudiamo il browser
driver.quit()

print("File 'bestsellers_with_prices.csv' creato con successo!")
# Out:
# File 'bestsellers_with_prices.csv' creato con successo!

# %%
# Carichiamo il file CSV che l'utente ha caricato
file_path = 'bestsellers_with_prices.csv'
df = pd.read_csv(file_path)

# Pulizia di base:
# - Rimuoviamo spazi iniziali/finali nei nomi
# - Puliamo i prezzi eliminando eventuali caratteri non numerici
df['Product Name'] = df['Product Name'].str.strip()
df['Price'] = df['Price'].str.strip()

# Creiamo un file Excel formattato
excel_file_path = 'bestsellers_with_prices.xlsx'
with pd.ExcelWriter(excel_file_path) as writer:
    df.to_excel(writer, sheet_name='Bestsellers', index=False)

excel_file_path
# Out:
# 'bestsellers_with_prices.xlsx'

# %%
# Now we look for the most loved products in the vibrator cathegory
# 2. Impostiamo il driver
service = Service(executable_path="chromedriver.exe") 
driver = webdriver.Chrome(service=service)

# 3. Apriamo la pagina
url = "https://www.beate-uhse.com/vibratoren/top-10?_gl=1*10wd421*_up*MQ..*_ga*OTkyOTEwNDM5LjE3NDU3NzU1MjQ.*_ga_172445XCFN*MTc0NTc3ODY4Ny4yLjAuMTc0NTc3ODY4Ny4wLjAuMA..*_ga_Q9MTBCRR20*MTc0NTc3ODY4Ny4yLjAuMTc0NTc3ODY4Ny4wLjAuMA.."
driver.get(url)

# 4. Aspettiamo il caricamento
time.sleep(5)

# 5. Prendiamo l'HTML
html = driver.page_source

# 6. Usiamo BeautifulSoup
soup = BeautifulSoup(html, "html.parser")

# 7. Troviamo tutti i prodotti
products = soup.find_all("article", class_="edc-product-block")

# 8. Estraiamo nome e prezzo
data = []
for product in products:
    # Troviamo il nome
    name_tag = product.find("a", class_="edc-product-block__title")
    name = name_tag.text.strip() if name_tag else "N/A"
    
    # Troviamo il prezzo
    price_tag = product.find("div", class_="edc-product-block__price-wrapper")
    price = price_tag.text.strip() if price_tag else "N/A"
    
    # Aggiungiamo alla lista
    data.append([name, price])

# 9. Salviamo su CSV
with open('vib_most_loved_with_prices.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Product Name', 'Price'])  # intestazioni colonne
    writer.writerows(data)

# 10. Chiudiamo il browser
driver.quit()

print("File 'vib_most_loved_with_prices.csv' creato con successo!")
# Out:
# File 'vib_most_loved_with_prices.csv' creato con successo!

# %%
# Carichiamo il file CSV
file_path = 'vib_most_loved_with_prices.csv'
df = pd.read_csv(file_path)

# Pulizia di base:
# - Rimuoviamo spazi iniziali/finali nei nomi
# - Puliamo i prezzi eliminando eventuali caratteri non numerici
df['Product Name'] = df['Product Name'].str.strip()
df['Price'] = df['Price'].str.strip()

# Creiamo un file Excel formattato
excel_file_path = 'vib_most_loved_with_prices.xlsx'
with pd.ExcelWriter(excel_file_path) as writer:
    df.to_excel(writer, sheet_name='Bestsellers', index=False)

excel_file_path
# Out:
# 'vib_most_loved_with_prices.xlsx'

# %%
# Definying a base palette
main_colors = {
    'F': '#B39DDB',       # Soft Purple (Feminine)
    'M': '#81D4FA',       # Sky Blue (Masculine)
    'M/F': 'palegreen',    # Pale Green (everybody)
    'Couple': '#FFCC80',  # Light Orange
    'External': '#80CBC4',  # Aqua green
    'Internal': 'bisque',  # Light pink
    'Bestseller': '#9575CD',  # Soft Violet
    'Most Loved': '#F48FB1',  # Pink
    'Cosmesi': '#AED581',  # Lime Green
    'Multicolor': '#B0BEC5',  # Neutral Grey
    'USB': 'lightgreen', # Soft green
    'Batteries': 'darkgray', # Gray
    'Electric': 'lightsteelblue' # Light Blue
}

# %%
# Call the file
file_path = 'bestsellers_with_prices_clean.xlsx'
df = pd.read_excel(file_path)

# # Calculate the percentage of each category
category_counts = df['Category'].value_counts()
category_percentages = (category_counts / category_counts.sum()) * 100

colors_in_order = [main_colors[cat] for cat in category_percentages.index]

import matplotlib.pyplot as plt
import pandas as pd

# Load the file
file_path = 'bestsellers_with_prices_clean.xlsx'
df = pd.read_excel(file_path)

# Calculate category percentages
category_counts = df['Category'].value_counts()
category_percentages = (category_counts / category_counts.sum()) * 100

# Define your color list (make sure main_colors is defined)
colors_in_order = [main_colors[cat] for cat in category_percentages.index]

# Create the plot and assign the bars
plt.figure(figsize=(6,4))
bars = plt.bar(category_percentages.index, category_percentages.values, color=colors_in_order)

plt.ylabel('Percentage of Products (%)')
plt.title('Distribution of Bestsellers by Category')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Add percentage labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height +1,
             f'{height:.1f}%', ha='center', va='bottom', fontsize=10)


plt.ylim(0, category_percentages.max() + 5)
plt.tight_layout()

plt.savefig('distribution_bestsellers_by_cat.png')

plt.show()

# %% [markdown]
# Beate Uhse's bestseller analysis reveals that the Cosmetics category already commands a significant portion of the market. This suggests a growing interest in products aimed at enhancing sexual wellbeing beyond traditional toys such as lubricants, massage oils, stimulating creams and pills, toy cleaners, and pheromone-infused perfumes.

# %%
# Cleaning column's prices in both datasets

file_path = 'vib_most_loved_with_prices_clean.xlsx'
df_loved = pd.read_excel(file_path)

file_path = 'bestsellers_with_prices_clean.xlsx'
df_best = pd.read_excel(file_path)

def clean_price(price):
    if isinstance(price, str):
        price = price.replace('€', '').replace(',', '.').strip()
    try:
        return float(price)
    except:
        return None

# Applying the function
df_best['Price_Clean'] = df_best['Price'].apply(clean_price)
df_loved['Price_Clean'] = df_loved['Price'].apply(clean_price)

# Creating the plot
plt.figure(figsize=(6,4))

box_colors = ['#9575CD', '#F48FB1']  # Bestseller = violet, Most Loved = soft red

boxprops = dict(linestyle='-', linewidth=1, color='black')
medianprops = dict(color='black', linewidth=1)

# Designing the boxes
box = plt.boxplot(
    [df_best['Price_Clean'].dropna(), df_loved['Price_Clean'].dropna()],
    tick_labels=['Bestsellers', 'Most Loved'],
    patch_artist=True,
    boxprops=boxprops,
    medianprops=medianprops
)

# Applying chosen colors
for patch, color in zip(box['boxes'], box_colors):
    patch.set_facecolor(color)

plt.title('Price Distribution: Bestsellers vs Most Loved Vibrators')
plt.ylabel('Price (€)')
plt.grid(axis='y')
plt.tight_layout()

plt.savefig('price_best_vs_most.png')

plt.show()

# %% [markdown]
# Figure 2 reveals that most-loved vibrators tend to fall into a higher price bracket than bestsellers. This suggests that while consumers may initially purchase lower-cost items, long-term satisfaction may be tied to more advanced or premium models.

# %% [markdown]
# ## 3.2 Internal vs. External Use

# %%
# Bar Chart for Usage with Percentages
use_counts = df_loved['Usage'].value_counts()
total = use_counts.sum()

clrs = ['bisque', '#80CBC4']

plt.figure(figsize=(6,4))
bars = plt.bar(use_counts.index, use_counts.values, color=clrs[:len(use_counts)])
plt.xlabel('Usage')
plt.ylabel('Number of Products')
plt.title('Distribution of Most Loved Vibrators by Use (Internal vs External)')
plt.grid(axis='y')

# Add percentage labels
for bar in bars:
    height = bar.get_height()
    pct = height / total * 100
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.3,
             f'{pct:.1f}%', ha='center', va='bottom', fontsize=10)

plt.ylim(0, use_counts.max() + 1)
plt.tight_layout()

plt.savefig('most_loved_usage.png')

# %% [markdown]
# As shown in Figure 3, the majority of Beate Uhse’s bestsellers are internal vibrators, reinforcing the hypothesis about penetration preference. External-only and couple-oriented toys occupy a smaller portion of the category.

# %% [markdown]
# **Beate Uhse – “Most Loved” Vibrators**
#
# * Use: Mostly designed for Internal stimulation
#
# * Power: Predominantly Rechargeable, reflecting a preference for convenience and sustainability
#
# * Price Point: Higher average and median price than bestsellers, suggesting a focus on quality and advanced features

# %% [markdown]
# ## 3.2 Technology and Materials
#
# In this section, we compare how material choices and technological features influence both popularity and user satisfaction.

# %%
# Bar Chart for Charge with Percentages
charge_counts = df_loved['Charge'].value_counts()
total = charge_counts.sum()

clr = ['lightgreen','darkgray','lightsteelblue']

plt.figure(figsize=(6,4))
bars = plt.bar(charge_counts.index, charge_counts.values, color=clr[:len(charge_counts)])
plt.xlabel('Charge Type')
plt.ylabel('Number of Products')
plt.title('Distribution of Most Loved Vibrators by Charging Method')
plt.grid(axis='y')

# Add percentage labels
for bar in bars:
    height = bar.get_height()
    pct = height / total * 100
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.3,
             f'{pct:.1f}%', ha='center', va='bottom', fontsize=10)

plt.ylim(0, charge_counts.max() + 1)
plt.tight_layout()

plt.savefig('most_loved_by_charging_method.png')

plt.show()

# %% [markdown]
# As shown in Figure 4, with 60% of the most loved vibrators using USB charging, it's clear that modern users value convenience, sustainability, and ease of use — pushing traditional batteries or electric plug-ins into the background.

# %%
# Comparison between Most loved vs Bestsellers in "charge"

# Clean & count Charge in Bestsellers
charge_counts_best = df_best['Charge'].value_counts()

# Clean & count Charge in Most Loved
charge_counts_loved = df_loved['Charge'].value_counts()

# Ignore N/P voices
charge_counts_best_cleaned = charge_counts_best.drop(labels=['N/P'], errors='ignore')
charge_counts_loved_cleaned = charge_counts_loved.drop(labels=['N/P'], errors='ignore')

# Combining datasets
charge_comparison = pd.DataFrame({
    'Bestsellers': charge_counts_best_cleaned,
    'Most Loved': charge_counts_loved_cleaned
}).fillna(0)

# Plot comparison Charge
charge_comparison.plot(
    kind='bar',
    figsize=(6,4),
    color=['#9575CD', '#F48FB1']
)

plt.title('Charging Method Comparison: Bestsellers vs Most Loved')
plt.xlabel('Charging Method')
plt.ylabel('Number of Products')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.legend(title='Group')
plt.tight_layout()

plt.savefig('charging_method_comparison.png')

plt.show()

# %% [markdown]
# **Figure 5 compares charging methods between bestselling and most loved vibrators**. While battery-powered toys still make up a notable portion of bestsellers, USB-rechargeable models dominate among the most appreciated products — suggesting a growing consumer preference for tech-savvy and sustainable options.
#
# >Insight: Rechargeable products are more appreciated over time suggesting that products users grow to love often differ from their initial, possibly more affordable, purchases. Accessibility and lower price may drive initial sales.

# %%
# Comparative exam for 'Usage' in Bestsellers and Most Loved
# First of all, let's clean the column

# Puliamo i dati 'Usage' (eliminare eventuali spazi strani)
df_best['Usage'] = df_best['Usage'].astype(str).str.strip()
df_loved['Usage'] = df_loved['Usage'].astype(str).str.strip()

# Creating separate price lists per cathegory (Internal vs External) in each grop

# Bestsellers
internal_prices_best = df_best[df_best['Usage'] == 'Internal']['Price_Clean'].dropna()
external_prices_best = df_best[df_best['Usage'] == 'External']['Price_Clean'].dropna()

# Most Loved
internal_prices_loved = df_loved[df_loved['Usage'] == 'Internal']['Price_Clean'].dropna()
external_prices_loved = df_loved[df_loved['Usage'] == 'External']['Price_Clean'].dropna()


# Combinig datasets
data_combined = pd.DataFrame({
    'Price': pd.concat([internal_prices_best, external_prices_best, internal_prices_loved, external_prices_loved]),
    'Group': (['Internal - Bestsellers'] * len(internal_prices_best)) +
             (['External - Bestsellers'] * len(external_prices_best)) +
             (['Internal - Most Loved'] * len(internal_prices_loved)) +
             (['External - Most Loved'] * len(external_prices_loved))
})

# Defining the palette
palette = {
    'Internal - Bestsellers': 'bisque',    # rosa soft
    'External - Bestsellers': '#9575CD',    # viola
    'Internal - Most Loved':   '#F48FB1',   # pink
    'External - Most Loved':   '#81D4FA'    # light blue
}

plt.figure(figsize=(7,5))

# Boxplot con palette definita
sns.boxplot(
    hue='Group',
    x='Group',
    y='Price',
    data=data_combined,
    palette=palette,
    showmeans=True,
    meanprops={"marker":"o", "markerfacecolor":"black", "markeredgecolor":"black"}
)

# Personalizziamo il grafico
plt.title('Price Comparison: Internal vs External\n for Bestsellers and Most Loved')
plt.ylabel('Price (€)')
plt.xlabel('')
plt.xticks(rotation=20)
plt.grid(axis='y')

plt.tight_layout()

plt.savefig('price_comparision_int_vs_ext')
plt.show()

# %% [markdown]
# **Figure 6: Price Comparison – Internal vs External Use in Bestsellers and Most Loved Vibrators**
#
# The boxplot above reveals several key insights:
#
# - Among **bestsellers**, internal vibrators dominate in number, but are also available at a broad range of prices including many affordable, entry-level options.
# - External-use vibrators in the **bestseller group** tend to cluster in the lower price range, reinforcing the idea that consumers often choose them as budget-friendly or add-on items.
# - Among **most loved** vibrators, the distinction between internal and external use is less pronounced both categories feature higher average prices and fewer low-cost options.
# - Notably, **external vibrators in the most loved group** show a strong preference for premium models. This suggests that when consumers choose external toys, they are willing to invest more possibly due to expectations around precision, material quality, or unique features like air pulse technology.
#
# In short, while internal vibrators dominate bestseller volume, the **most telling contrast lies in how external toys are valued**: budget-friendly when first bought, but premium when truly appreciated.

# %% [markdown]
# <h3>Summary Comparison – Beate Uhse Vibrators: Bestsellers vs Most Loved</h3>
# <table style="border-collapse: collapse; width: 100%;">
#   <thead>
#     <tr style="background-color: #f2f2f2;">
#       <th style="border: 1px solid #ccc; padding: 8px;"><b>Feature</b></th>
#       <th style="border: 1px solid #ccc; padding: 8px;"><b>Bestsellers</b></th>
#       <th style="border: 1px solid #ccc; padding: 8px;"><b>Most Loved</b></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="border: 1px solid #ccc; padding: 8px;">Use</td>
#       <td style="border: 1px solid #ccc; padding: 8px;">Mixed, but external toys more common</td>
#       <td style="border: 1px solid #ccc; padding: 8px;">Mostly internal stimulation</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ccc; padding: 8px;">Power</td>
#       <td style="border: 1px solid #ccc; padding: 8px;">More variety: battery-powered and hybrid models</td>
#       <td style="border: 1px solid #ccc; padding: 8px;">Predominantly USB-rechargeable</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ccc; padding: 8px;">Price Point</td>
#       <td style="border: 1px solid #ccc; padding: 8px;">Lower average and median price</td>
#       <td style="border: 1px solid #ccc; padding: 8px;">Higher average and median price</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ccc; padding: 8px;">User Preference</td>
#       <td style="border: 1px solid #ccc; padding: 8px;">Reflects accessibility and entry-level appeal</td>
#       <td style="border: 1px solid #ccc; padding: 8px;">Indicates preference for quality, durability, and features</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# >Insights on Beginner vs. Advanced Use
# This pattern reflects not just a product choice — but a personal evolution: from accessibility and experimentation to awareness, preference, and long-term enjoyment.

# %% [markdown]
# # 4 Comparative Market Study: Europe & Beyond
#
#
# ## 4.1 Use Frequency, Preferences, and Satisfaction
#
# To understand how sex toy use and its perceived impact vary across regions, we draw on a large-scale, cross-sectional study involving 11,944 participants from six European countries: Denmark, Sweden, Norway, Finland, France, and the United Kingdom. [The study](https://doi.org/10.1080/00224499.2024.2304575) explored ownership patterns, contexts of use, and their correlations with sexual, relationship, and life satisfaction.
#
# - **Ownership**: Over 50% of participants in all countries reported having owned at least one sex toy.
# - **Most commonly owned items**: Dildos and vibrators, followed by handcuffs, penis rings, and anal toys.
# - **Usage context**: 55–65% used toys with a steady partner; 10–15% with casual partners.
# - **Country differences**:
#   - **France** had the lowest toy ownership.
#   - **UK** had the highest vibrator ownership (approx. 80%).
#
# **Satisfaction Scores (Average)**
#
# | Country   | Sexual Sat. | Life Sat. | Relat. Sat. |
# |-----------|-------------|-----------|-------------|
# | France    | 3.87        | 3.57      | 3.88        |
# | Denmark   | 3.73        | 3.50      | 3.96        |
# | Sweden    | 3.69        | 3.52      | 3.92        |
# | UK        | 3.58        | 3.40      | 4.04        |
# | Finland   | 3.58        | 3.38      | 3.80        |
# | Norway    | 3.59        | 3.40      | 3.79        |
#
# > *Note: France ranks highest in sexual satisfaction, while the UK leads in relationship satisfaction. Nordic countries are tightly clustered across all dimensions.*
#
# These findings challenge cultural stereotypes. While ownership and use patterns differ slightly, satisfaction outcomes are relatively consistent — pointing to:
# - A growing alignment of sexual attitudes in Western Europe;
# - The normalization of sex toys as part of everyday erotic culture;
# - The influence of e-commerce and discreet shipping on access.
#
# France’s case is particularly striking: despite low ownership, it leads in sexual satisfaction — suggesting that erotic comfort isn’t determined solely by product use. Meanwhile, the UK’s high ownership and strong relationship scores may reflect a greater openness to shared erotic practices.
#
#
# ## 4.2 Market Insights
#
# The European sex toy market shows strong signs of growth, diversification, and cultural adaptation:
#
# - According to Straits Research, the market is projected to grow from **$12.44 billion in 2024** to **$21.70 billion by 2033**, with a **CAGR of 7.2%**.
# - Products for women currently make up **48% of the market**, and this segment is expected to grow at a **7.67% CAGR** by 2030.
# - Distribution is dominated by **e-commerce**, which accounted for over **60% of sales in 2021** and is forecasted to increase steadily (7.45% CAGR by 2030).
#
# **Top national markets in Europe** include:
# - **Germany**, **Italy**, **France**, **the UK**, and **Denmark**.
# - **Spain** is also a global top buyer, and Southern European countries (Spain, Italy, Greece, Portugal) report a **34% openness rate** toward exploring novel erotic practices — slightly higher than their Northern counterparts.
#
# Germany, in particular, shows strong adoption rates:
# - **52%** of adults use sex toys during partnered sex.
# - **45%** report using them during solo masturbation (source: Grand View Research).
#
# Search and digital behavior reflect further regional interest:
# - A report by TechySex.com ranks **Sweden** highest in sex toy-related online searches, followed by **Denmark**, the **UK**, and **Norway**.
#
# Lastly, a 2023 study published in *Sexual Medicine* based on Google Trends data (2009–2023) found:
# - A **sustained rise in interest for vibrators and masturbators**.
# - A **decline in dildo-related searches** since around 2016.
#
# These combined insights illustrate both growing consumer demand and a shift toward more technologically advanced, self-care–oriented products.
#
#
# ## 4.3 Interpretation Notes
#
# When we triangulate academic research, market data, and digital behavior, a number of regional patterns emerge:
#
# - **Nordic countries** (e.g. Sweden, Denmark) show consistently high levels of both market engagement and online interest. This points to a cultural openness and digital fluency around erotic tools.
#
# - **Germany** reflects a mature, normalized market with high rates of toy use in both solo and partnered contexts — likely supported by long-standing retail infrastructure and less social stigma.
#
# - The **UK** stands out for its high vibrator ownership and top-ranking relationship satisfaction, possibly indicating greater openness to shared pleasure practices within couples.
#
# - **Southern Europe** (e.g. Spain, Italy, Greece) demonstrates strong buying power and cultural willingness to explore new erotic experiences, challenging assumptions of traditional conservatism.
#
# Across all regions, one trend is unmistakable: the growing popularity of technologically sophisticated toys — such as **air pulse stimulators**, **wand massagers**, and **multi-function devices** — reflects a cultural shift toward **innovation, self-care, and refined eroticism**.
#
# In sum, while what people buy may vary by culture, **how** they use these products — and the values behind those choices — tell us even more about evolving attitudes toward intimacy, pleasure, and personal agency.

# %%
# Dati di soddisfazione per nazione
countries = ['France', 'Denmark', 'Sweden', 'UK', 'Finland', 'Norway']
sexual = [3.87, 3.73, 3.69, 3.58, 3.58, 3.59]
life = [3.57, 3.50, 3.52, 3.40, 3.38, 3.40]
relationship = [3.88, 3.96, 3.92, 4.04, 3.80, 3.79]

x = range(len(countries))

# Imposta dimensioni
plt.figure(figsize=(6,4))

# Line plot comparativo
plt.plot(x, relationship, marker='o', label='Relationship Satisfaction', color= 'tomato')
plt.plot(x, sexual, marker='o', label='Sexual Satisfaction', color = 'blueviolet')
plt.plot(x, life, marker='o', label='Life Satisfaction', color = 'seagreen')

# Etichette e asse X
plt.xticks(x, countries)
plt.title('Satisfaction Scores by Country')
plt.ylabel('Average Score (1–5)')
plt.ylim(3.3, 4.1)
plt.grid(True)
plt.legend()
plt.tight_layout()

plt.savefig('satisfaction_scores_by_country')
plt.show()

# %% [markdown]
# **Figure 7 visualizes average satisfaction scores across six European countries**. While the UK leads in relationship satisfaction, France ranks highest in sexual satisfaction. The Nordic countries cluster closely, suggesting consistent patterns of moderate-to-high satisfaction across all dimensions. These scores match the patterns observed in the earlier table (Section 4.1), reinforcing both regional distinctiveness and shared trends.

# %% [markdown]
# ## Generational Patterns in Sex Toy Use
#
# Although no direct age data is available from Beate Uhse's online shop, both academic research and product-level observations suggest a clear generational pattern in sex toy consumption.
#
# ###  What the research says
#
# A large-scale study across Denmark, Norway, Sweden, Finland, France, and the UK (_Do Sex Toys Make Me Satisfied_), found that **younger people are significantly more likely to use sex toys**. Age was the strongest predictor of usage, especially for solo play. The same study links younger usage to greater sexual openness, digital access, and lower stigma.
#
# ###  What the products show
#
# From the manually extracted bestseller data, we observe that:
#
# - The **most sold toys** are low-cost (mostly under €25)
# - They are largely **internally focused** (e.g. classic vibrators, plugs)
# - Many are marketed as **beginner-friendly** and battery-operated
# - Brands like *EasyToys* dominate this segment
#
# By contrast, the **most loved toys** — as reflected in reviews and personal observation — tend to::
#
# - Cost significantly more (often €50–140)
# - Use **advanced technology** (USB charging, air pulse, wand motors)
# - Are often **external toys**, especially clitoral stimulators
# - Prioritize **material quality** (premium silicone, ergonomic shapes)
#
# ##  Interpretation Notes
#
# This divide likely reflects **two overlapping trends** inferred based on product characteristics, price sensitivity, and known user behavior trends:
#
# | Segment          | Likely Age Group | Motivation         | Behavior                                |
# |------------------|------------------|--------------------|------------------------------------------|
# | Bestsellers       | 18–30            | Accessibility       | First-time users, gift purchases         |
# | Most Loved        | 30+              | Experience & Quality| Self-knowledge, repeat buyers, design-savvy |
#
# In essence:
#
# - **Youth buys more** – driven by price, accessibility, and curiosity
# - **Experience loves better** – driven by sensuality, quality, and control
#
# Even without user-level age data, the **price and technology gap** between bestsellers and most loved products reflects a generational distinction in how erotic products are chosen and valued.

# %% [markdown]
# # 5 Product Categories & Emerging Trends
#
# ## 5.1 Qualitative Insights: Material Innovation
#
# The development of modern materials has allowed dildos to diversify in form, color, and texture, making them more accessible and tailored to different preferences. Modern sex toys increasingly prioritize not only safety and aesthetics, but also environmental impact and user-specific ergonomics, features enabled by new-generation materials.(¶6).
#
# > **Source:** Wikipedia – [Sex toy > History](https://en.wikipedia.org/wiki/Sex_toy)
# > Extracted from `scraped_data.json`, paragraphs 1–9.
#
# ## 5.2 Case Study: CalExotics – Feminine Innovation and Firsts
#
# As the first sex toy company founded and operated by a woman (1994), and global leader in innovation, there is a long list of accomplishments attributed to CalExotics. Many of these have become industry standards, with their roots traced back to the pioneering spirit of Susan Colvin and her team.
#
# CalExotics was the first to…
#
# * Introduce feminine colors to intimate massagers
# * Release a waterproof line of toys
# * Introduce remote control egg-style intimate massager
# * Offer manufacturer warranties for intimate products
# * Have an all-women product development team
# * Create 100% premium silicone intimate products
# * Introduce rechargeable rabbit-style vibrators
# * Manufacture a talking vibrator
# * Create pulsating intimate massager made in the USA
# * Bring an eco-friendly, solar-powered intimate toy to market
# * Design butterfly-style intimate massagers
# * Manufacture a wireless charging massager with built-in sanitizing capabilities
#
# Together, these milestones illustrate CalExotics' role in shifting the industry toward inclusivity, personalization, and technological advancement — especially for women-led pleasure.

# %%
# Now we look for the most loved products in the vibrator cathegory
# We'll use a particular driver to distract :)
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service)

# Open the page
url = "https://calexotics.com/best-sellers/"
driver.get(url)

# Wait for loading
time.sleep(5)

# Taking the HTML
html = driver.page_source

# Using BeautifulSoup
soup = BeautifulSoup(html, "html.parser")

# Finding products's titles (looked for them, first of all with F12) (h4.card-title > a)
product_blocks = soup.find_all("h4", class_="card-title")

# 8. Extracting name, price and link from the <a> tag 
products = []
for block in product_blocks:
    a_tag = block.find("a")
    if a_tag and a_tag.has_attr("aria-label") and a_tag.has_attr("href"):
        full_label = a_tag["aria-label"]
        link = "https://calexotics.com" + a_tag["href"]
        if ',' in full_label:
            name, price = map(str.strip, full_label.split(',', 1))
        else:
            name = full_label.strip()
            price = ""
        products.append((name, price, link))

# 9. Saving in a CSV file
with open('bestsellers_calexotics.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Product Name', 'Price', 'Product URL'])
    for name, price, link in products:
        writer.writerow([name, price, link])
        
# Closing the browser
driver.quit()

print("File 'bestsellers_calexotics.csv' succesfully created!")
# Out:
# File 'bestsellers_calexotics.csv' succesfully created!

# %%
# Loading the CSV file
df = pd.read_csv("calexotics_all_products.csv")

# Saving as an Excel file
df.to_excel("calexotics_all_products.xlsx", index=False)

print("Excel file created: calexotics_all_products.xlsx")
# Out:
# Excel file created: calexotics_all_products.xlsx

# %%
# Loading the XLSX
df = pd.read_excel("calexotics_all_products.xlsx")

# Setup driver
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service)

materials_list = []

# Looking for some typical materials
known_materials = ["Silicone", "ABS", "TPR", "TPE", "Metal", "Plastic", "Glass", "PVC", "Latex", "Stainless Steel"]

for index, row in df.iterrows():
    url = row["Product URL"]
    try:
        driver.get(url)
        time.sleep(5)
        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")

        text = soup.get_text(separator=" ").lower()
        found = []

        for mat in known_materials:
            if mat.lower() in text and mat not in found:
                found.append(mat)

        materials_list.append("; ".join(found) if found else "Not specified")

    except Exception as e:
        print(f"Errore su {url}: {e}")
        materials_list.append("Error")

driver.quit()

# Adding the column to the df
df["Material"] = materials_list

# Saving again the file
df.to_excel("calexotics_all_products_with_materials.xlsx", index=False)

print("Updated file saved as 'calexotics_all_products_with_materials.xlsx'")
# Out:
# Updated file saved as 'calexotics_all_products_with_materials.xlsx'

# %%
# Loading the dataset updated with Usage
df = pd.read_excel("calexotics_all_products_with_materials_usage.xlsx")

# 1 analisis: Distribution of materials
# We'll divide materials one by one (es. "Silicone; ABS")
from collections import Counter

all_materials = []
for row in df['Material'].dropna():
    for mat in row.split(';'):
        all_materials.append(mat.strip())

material_counts = pd.Series(Counter(all_materials)).sort_values(ascending=False)

# Bar chart
plt.figure(figsize=(6,4))
material_counts.plot(kind='bar', color='pink')
plt.title("Distribution of materials in CalExotics")
plt.ylabel("Number of products")
plt.xlabel("Material")
plt.tight_layout()
plt.savefig('materials_in_calexotics')

# %% [markdown]
# Figure 8 shows that **CalExotics heavily favors premium materials** such as medical-grade silicone and ABS plastic, while avoiding lower-end compounds like jelly or porous rubber. This aligns with the brand's commitment to safety, durability, and high-quality user experience.

# %%
# 2nd analysis: Distribution by usage (Internal/External/BDSM) --
col_cal = ['#80CBC4','bisque','tomato']

if 'Usage' in df.columns:
    usage_counts = df['Usage'].value_counts()
    plt.figure(figsize=(6,4))
    usage_counts.plot(kind='bar', color = col_cal)
    plt.title("Type of Usage")
    plt.ylabel("Number of products ")
    plt.xlabel("Usage")
    plt.tight_layout()
    plt.savefig('type_of_usage')

# %% [markdown]
# Figure 9 categorizes CalExotics products by usage type. Internal toys remain the dominant group, but there is significant representation of external and couple-oriented toys — reflecting a product line that accommodates a range of preferences and sexual contexts.

# %%
# 3rd. analysis: Middle price per type of use
# Cleaning the price column, removing the dollar sign and converting into float

df['Price_clean'] = df['Price'].str.replace("$", "", regex=False).astype(float)

price_cal = ['tomato','bisque','#80CBC4']

if 'Usage' in df.columns:
    avg_price = df.groupby("Usage")["Price_clean"].mean().sort_values()
    plt.figure(figsize=(6,4))
    avg_price.plot(kind='bar', color=price_cal)
    plt.title("Price by Usage Type")
    plt.ylabel("Middle price ($)")
    plt.xlabel("Usage")
    plt.tight_layout()
    plt.savefig('Price_by_Usage_Type.png')

# %% [markdown]
# Figure 10 shows the median price of CalExotics products by usage type. External toys are slightly more expensive than internal ones, while BDSM items have a noticeably lower median price. This may reflect simpler design in BDSM accessories or lower-cost entry products, compared to the often tech-enhanced features found in external and internal vibrators.

# %%
# PIE CHART + TABELLA: distribution Target (M / F / COUPLE) ---
df = pd.read_excel("calexotics_all_products_with_materials_usage.xlsx")
if 'Target' in df.columns:
    target_counts = df['Target'].value_counts()

    col_target = ['#B39DDB','#81D4FA', '#FFCC80']
    # Pie chart
    plt.figure(figsize=(4,4))
    plt.pie(target_counts, labels=target_counts.index, autopct='%1.1f%%', startangle=140, colors=col_target[:len(charge_counts)])
    plt.title("Distribution per target (M / F / COUPLE)")
    plt.axis('equal')
    plt.tight_layout()
    plt.savefig('distribution_per_target')

    # Tabella a parte
    print("\n Number of products for each target:\n")
    display(target_counts.to_frame(name="Number of products"))
    
else:
    print("'Target' column not found.")
# Out:
#  Number of products for each target:
#         Number of products
# Target
# F                       22
# M                       11
# COUPLE                   2

# %% [markdown]
# **Figure 11 illustrates the distribution of CalExotics products by target audience**. Toys designed for female users dominate the catalog, while couple-oriented products are less frequent. Items explicitly marketed toward male users make up a smaller share, suggesting either a narrower product range or more gender-neutral positioning in this category.

# %% [markdown]
# ## 5.3 Brand Comparison: CalExotics vs. Beate Uhse
#
# To explore how product positioning and branding strategies vary across companies, the table below compares the bestselling items from CalExotics and Beate Uhse. While both target a broad consumer base, their catalogs differ significantly in terms of audience focus, pricing, technology, and cultural tone.
#
# This comparison draws from previously scraped product data and manually curated bestseller selections.

# %% [markdown]
# | Feature                  | **CalExotics (bestsellers)**                    | **Beate Uhse (bestsellers)**                       | Interpretive Note                                                  |
# |--------------------------|--------------------------------------------------|---------------------------------------------------|---------------------------------------------------------------------|
# | **Target: Female (F)**   | 31.4%                                            | 62.9%                                             | Beate Uhse shows a stronger focus on a female audience              |
# | **Target: Male (M)**     | 17.1%                                            | 32.4%                                             | Beate offers more male-oriented products                           |
# | **Target: Couples**      | 51.5%                                            | Marginal                                          | CalExotics is heavily focused on shared, couple-oriented products  |
# | **Cosmetics**            | (not in bestsellers)                            | (34% of sample)                                  | CalExotics sells lubricants, but none appear among bestsellers     |
# | **Average Price**        | Higher                                           | More accessible                                  | Positioned mid-to-high vs. more entry-level approach               |
# | **Technology**           | High (Bluetooth, app-compatible, rechargeable)  | Lower or absent                                   | CalExotics strongly emphasizes innovation                          |
# | **Main Materials**       | Silicone dominant                                | Silicone + mix of others                         | Both favor silicone; CalExotics shows more consistency             |
# | **Visual Language**      | Modern, soft-clinical, inclusive                 | Seductive, direct, traditionally erotic           | Cultural and branding styles differ significantly                  |

# %% [markdown]
# # 6 Partnered vs. Solo Use
#
# Chapter 6 explores how sex toys are used in solo versus partnered contexts, and how product design, marketing, and social narratives shape those choices. This iconic ad from Sh! — a brand founded to champion women's pleasure — captures the spirit of solo empowerment.
#
# <table>
#   <tr>
#     <td>
#       <img src="images\Sh!_Our_first_print_ad.jpg" alt='Sh!s first print ad' width="400"><br>
#       <sub><b>"Pleasure is power</b><br>
#       We claim our right to pleasure. In doing so, we become revolutionists who can take on the world."</sub>
#     </td>
#    </tr>
# </table>
#
#
# ## 6.1 Sh! – Reclaiming Pleasure Beyond the Phallus
#
# When Kathryn Hoyle co-founded Sh! in the early 1990s, the mainstream sex toy industry was still flooded with enormous, phallic replicas—tools designed more for spectacle than genuine female pleasure. “Everything was dick-shaped,” Hoyle recalls. “Because all women’s pleasure is at the end of a dick.” But Sh! was born out of a different scene, London’s lesbian S&M community, and carried with it a bold, disruptive ethos: that women, queer people, and anyone with a vulva deserved pleasure on their own terms.
#
# From the start, Sh! rejected toys that mimicked genitals. “We’re saying toys aren’t replicas or replacements for anything. They’re toys!” Hoyle insists. Their shelves filled instead with sleek, colorful, and unapologetically unrealistic designs, joyful tools to explore pleasure solo, without shame or scripts. At a time when clitoral stimulation was largely ignored, Sh! prioritized it. “There were very, very few toys we actually wanted to stock, so we started producing them. Since then, there has been more shift towards toys for women’s pleasure... the focus on the clitoris has gone way up.”
#
# More than a boutique, Sh! became a sanctuary. Customers who had survived sexual trauma, struggled with vaginismus, or lived through cancer found in Sh! not just products, but healing. One woman wrote to share how her visit helped her reclaim her body after rape—something years of therapy hadn’t managed. Although the physical store in Hoxton closed during the COVID-19 pandemic, Sh! continues to thrive online, offering not just products but also digital consultations, educational blogs, and ongoing support through its website and campaigns.
#
# In a world still obsessed with “penetration as sex” and “everything else as foreplay,” Sh! challenged the script. It invited people, especially women, to center their own needs, whether partnered or alone. “If I had one wish,” Hoyle says, “I would get rid of the concept of foreplay”. Because at Sh!, pleasure itself is always the main event.

# %%
# Use Chrome driver
service = Service(executable_path="chromedriver.exe")
driver = webdriver.Chrome(service=service)

# Open the page
url = "https://sh-womenstore.com/collections/best-sellers"
driver.get(url)
time.sleep(5)

# Parse con BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")
driver.quit()

# Find the blocks for products
product_cards = soup.find_all("div", class_="card-wrapper")

# Extract
products = []

for card in product_cards:
    title_tag = card.find("h6", class_="collection-product-title")
    price_tag = card.find("span", class_="collection-product-price")
    link_tag = card.find("a", href=True)

    name = title_tag.text.strip() if title_tag else "N/A"
    price = price_tag.text.strip() if price_tag else "N/A"
    link = "https://sh-womenstore.com" + link_tag["href"] if link_tag else "N/A"

    products.append((name, price, link))

# Save the CSV
with open("sh_best_sellers.csv", mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Product Name", "Price", "Product URL"])
    writer.writerows(products)

print("Great! File 'sh_best_sellers.csv' succesfully created.")
# Out:
# Great! File 'sh_best_sellers.csv' succesfully created.

# %%
# Load the CSV
df = pd.read_csv("sh_best_sellers.csv")

# Clean Price column: remove signs like "From €" o "€"
df["Price"] = df["Price"].str.replace("From", "", case=False)
df["Price"] = df["Price"].str.replace("€", "", regex=False)
df["Price"] = df["Price"].str.replace(",", ".").str.strip()

# If possible, converte in float
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")

# Export in Excel
df.to_excel("sh_best_sellers_cleaned.xlsx", index=False)

print("File 'sh_best_sellers_cleaned.xlsx' succesfully created.")
# Out:
# File 'sh_best_sellers_cleaned.xlsx' succesfully created.

# %%
try:
    bu = pd.read_excel("bestsellers_with_prices_clean.xlsx")
except Exception as e:
    print(f"Error reading file: {e}")

# %%
# Comparative Analysis 3 brands in "Bestsellers"
luxury_palette = ['bisque', 'crimson', 'orangered']  

# Load datasets
sh = pd.read_excel("sh_best_sellers_cleaned_with_usage.xlsx")
cal = pd.read_excel("calexotics_all_products_with_materials_usage.xlsx")
bu = pd.read_excel("bestsellers_with_prices_clean.xlsx")

# Standardize brand labels
sh['Brand'] = 'Sh!'
cal['Brand'] = 'CalExotics'
bu['Brand'] = 'Beate Uhse'

# Uniform column naming if needed
for df in [sh, cal, bu]:
    df.rename(columns=lambda x: x.strip().capitalize(), inplace=True)

# Merge datasets and focus on female products
combined = pd.concat([sh, cal, bu], ignore_index=True)
f_only = combined[combined['Target'] == 'F']

# --- ANALYSIS 1: Internal vs External ---
plt.figure(figsize=(7,4))
sns.countplot(data=f_only, x='Usage', hue='Brand', palette=luxury_palette)
plt.title("Usage Type Comparison (Internal vs External) – Female Products")
plt.ylabel("Number of Products")
plt.xlabel("Usage")
plt.legend(title='Brand')
plt.tight_layout()

plt.savefig('usage_type_comparison')
plt.show()

# %% [markdown]
# Figure 13 compares internal and external toy types in female-targeted products, highlighting differences between bestsellers and most loved items.

# %% [markdown]
# **Interpretation: Usage Type in Female-Targeted Products**
#
# The distribution of usage types shows that internal products dominate across all three brands. Sh! and Beate Uhse exhibit similar ratios of internal to external toys, while CalExotics leans more heavily on external-use items, resulting in a more balanced profile.
#
# Note: Counts are based on bestsellers products listed online and are not normalized.

# %%
# Cleaning and Price conversion
# Note I'll care only about F targets. I create a copy for the pleasure of py
f_only = combined[combined['Target'] == 'F'].copy()

# 1. Create a new clean column for price
f_only['Price_clean'] = (
    f_only['Price']
    .astype(str)
    .str.replace('$', '', regex=False)  # Remove simbolo $
    .str.replace('€', '', regex=False)  # Remove simbolo €
    .str.replace(',', '.', regex=False) # Subsitute virgole with dot if necessary
    .str.strip()
)

# 2. Convert in number
f_only['Price_clean'] = pd.to_numeric(f_only['Price_clean'], errors='coerce')

# 3. Convert only CalExoticsfrom dollars to euro
usd_to_eur = 0.93  # Usa il tasso di cambio che preferisci
f_only.loc[f_only['Brand'] == 'CalExotics', 'Price_clean'] *= usd_to_eur

# 4. Check if prices are finally ok
print(f_only.groupby('Brand')['Price_clean'].describe())
# Out:
#             count       mean        std      min      25%      50%       75%  \
# Brand
# Beate Uhse   15.0  40.519333  43.438396   8.9900  11.9900  19.9900   49.9900
# CalExotics   22.0  78.913882  29.547912  37.1907  59.5107  72.9957   96.7107
# Sh!          17.0  75.008824  46.985996  19.9500  34.9500  70.9500  106.9500
#
#                  max
# Brand
# Beate Uhse  164.9600
# CalExotics  134.8407
# Sh!         178.9500

# %%
# Comparison Boxplots with middle prices
luxury_palette = ['bisque', 'crimson', 'orangered']  

plt.figure(figsize=(7,4))
ax = sns.boxplot(data=f_only, x='Brand', y='Price_clean', hue= 'Brand', palette=luxury_palette)
plt.title("Price Distribution Bestsellers – Female Products")
plt.ylabel("Price (€)")
plt.xlabel("")

# Calculate mean and add labels
brand_means = f_only.groupby("Brand")["Price_clean"].mean()

for i, brand in enumerate(brand_means.index):
    mean_price = brand_means[brand]
    ax.text(i, mean_price + 1, f"€{mean_price:.2f}", 
            ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')
    
plt.tight_layout()

plt.savefig('comparison_price_distribution_bestsellers')
plt.show()

# %% [markdown]
# **Price Distribution – Female Products**
#
# This box plot shows the price distribution of female-targeted products across the three brands.
#
# - **Sh!** features the lowest median price (€40.52), a wider overall range, and a few standout high-end items.
# - **CalExotics** centers around a higher median (€78.91) with a narrower, more consistent price spread — suggesting a mid-premium positioning.
# - **Beate Uhse** offers a slightly lower median (€75.01), but a strong concentration of very low-cost products.
#
# Interestingly, despite these differences in pricing, both Sh! and Beate Uhse show similar proportions of internal-use products. This raises the question of whether internal/external orientation correlates with pricing strategy or a younger target audience. Further user data would be needed to confirm or reject that hypothesis.

# %% [markdown]
# # 7 Visual & Symbolic Design
#
# ## 7.1  Reimagining Pleasure: Beyond Anatomical Realism
#
# In recent years, a growing segment of the sex toy industry has radically redefined the aesthetics of pleasure. Moving beyond anatomical realism, brands like Bad Dragon, Odyssey Toys, and numerous queer-friendly artisans on platforms like Etsy have embraced fantasy, sci-fi, and monster-inspired designs. These toys are not only objects of desire, but also playful provocations, challenging normative expectations of sexuality, anatomy, and gender identity.

# %%
# Scrapping Bad Dragon
# %%capture
product_ids = ["kyel","chanceflared","flint","krampus","chico","valentino","sugarstar","tako","lilfusion","mystic","razor","echohorn","sleipnir","ridemystic","janinemuzzle","hazel","vasu","orochisheath","eggplug","bumblehooves","janine","chancesheath","tailstretcher","lilseadragon","demondick","roland","desi","amon","tempestt","bo","varka","rideika","david","blaze","hanzo","echo","rex","haiku","diego","candy","moko","habu","seraphina","winstonstongue","breeder","ikasheath","bishop","archercut","sveinn","nova","flintsheath","plungerflop","marcel","crackerslegacy","ovipositor","baron","nocturne","lilnightdrake","chanceunflared","fenrir","magnussheath","nox","vector","kippy","reggie","andre","delmar","votan","tucker","lenneth","abyss","leilani","fiona","mandrake","crackers","clayton","crackerssheath","ridley","meng","rideorochi","austin","crash","luka","stan","aquadrax","kelvin","kahn","xar","cole","davidsheath","orochi","jerry","kragg","ika","lilcockatricelegacy","vergil","tyson","nokken","duke","dukemuzzle","davidpaw","slater","rideflint","apollo","alice","spritz","lilcockatrice","taurion","helius","archeruncut","hanns"]

# List to save results
results = []

for pid in product_ids:
    url = f"https://bad-dragon.com/api/products/{pid}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        name = data.get("name", "N/A")
        price = data.get("basePrice", "N/A")
        toy_type = data.get("type", "N/A")
        description = data.get("seoDescription", "N/A")
        link = f"https://bad-dragon.com/products/{pid}"

        results.append((name, price, toy_type, description, link))
        print(f"✓ {name} added")
    else:
        print(f"❌ Failed to load {pid}")

# Save the CSV
with open("bad_dragon_top.csv", mode="w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Name", "Price", "Type", "Short Description", "Product URL"])
    writer.writerows(results)

print("✅ File 'bad_dragon_top.csv' creato con successo.")
# Out:
# UsageError: Line magic function `%%capture` not found.

# %% [markdown]
# ### 7.1.1 Fantasy Typologies and Their Audiences
#
# | Typology                     | Description / Style                             | Primary Audience                                  |
# |-----------------------------|--------------------------------------------------|--------------------------------------------------|
# | **Mythological Creatures**  | Dragons, demons, gods; exaggerated ridges, scales | Queer/kink communities, fantasy fans             |
# | **Aliens / Sci-Fi Forms**   | Smooth, glowing, tentacled, non-anatomical shapes | Sci-fi fans, gender non-conforming users         |
# | **Animalistic Forms**       | Canine, equine, tentacle-based or hybrid species | Furries, kink/BDSM users                         |
# | **Fandom-Inspired**         | Based on D&D, hentai, fanfiction characters      | Online fan communities, collectors               |
# | **Roleplay Tools**          | Suction cups, firmness levels, ovipositors       | Immersive roleplayers, kink users                |
#
#
# These forms are often hyper-stylized, grotesque, or exaggerated—offering both roleplay immersion and a sense of otherworldly transgression.
#
# ### 7.1.2 Technology & Materials
#
# These toys are typically made from **platinum-cured, medical-grade silicone**, ensuring both safety and durability.. While some brands signal inclusivity through non-gendered language, the primary audience overlaps with:
#
# Despite the playful tone, these toys are often **engineered with precision**, incorporating suction cups, firmness levels, and even “ovipositors” (egg-laying dildos) for immersive roleplay.
#
# ### 7.1.3 From Object to Character
#
# The product names themselves play a key role in brand identity:
#
# Examples include:
#
# * “Chance the Stallion”
#
# * “David the Werewolf”
#
# * “Nox the Night Drake”
#
# Descriptions often blend:
#
# * Erotic language (“thick ridges made for deep stretch”)
#
# * Playful tones (“a worthy toy for those who dare”)
#
# * Empowering messaging (“crafted for those who write their own stories”)
#
# * The tone is explicitly inclusive, imaginative, and unapologetically deviant.

# %%
# Creating a WordCloud for insights and beauty
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import re
import numpy as np

# STEP 1: Load your shape
mask_image = np.array(Image.open("stan.png"))

# STEP 2: Get site text
# Use a sample text (short mockup, since I can't fetch from URL here)
text = (
"Ky'el® is an anthro feline dildo with a slightly curved shaft featuring small nubs and graspable balls at the base. It’s an excellent toy for beginners and experienced toy users alike. Chance Flared is the ultimate anthro horse sex toy. Sculpted by hand with a medial ring and bulbous head, you'll want to grab your saddle and hop on. Flint® is a dildo designed with ridges, studs, and a thick girth. Its simulated foreskin and strong curvature will stimulate you in all the right places. Krampus the Satyr™ is a mythological-inspired highly textured dildo with fine details and ridges for a sensation-riddled experience.Test out our famous Cumlube and Cumtube with your Lil' Squirt; a uniquely designed lube application accessory.Valentino the King of Hearts™ is a highly textured anthro-bear dildo with a tapered head for easier insertion.Sugar Star is an anthro pony masturbation sleeve with detailed lips, a smooth entrance, and core of criss cross ridges and nubs.Tako® the Tentacle is a dildo with a subtle texture, a spade-shaped tip, and an increasingly girthy shaft covered in pleasurable suckers.Test out our famous Cumlube and Cumtube with your Lil' Squirt; a uniquely designed lube application accessory.Mystic® is a unicorn horn dildo that has a smooth, soft-textured shaft with a rounded tip, a spiral shape and an ornately styled base.")
# STEP 3: Clean and filter text
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    words = text.split()
    words = [word for word in words if len(word) >= 3]
    return ' '.join(words)

cleaned = clean_text(text)

# STEP 4: Set of stopwords
stopwords = set(STOPWORDS)
# Optional: Custom stopwords here
custom_words = {'lined','cris'}  
stopwords.update(custom_words)

# STEP 5: Generate cloud with mask
wordcloud = WordCloud(width=1000, height=1000, background_color='black', colormap='hsv', # possible colors: brg; gist_rainbow; jet; gist_ncar; hsv
                      stopwords=stopwords, mask=mask_image,
                      contour_width=1, contour_color='black').generate(cleaned)

# STEP 6: Show it
plt.figure(figsize=(8,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

wordcloud.to_file("wordcloud_stan.png")

# %% [markdown]
# Figure 15 visualizes the most frequently used words in Bad Dragon’s product descriptions. Fewer medical or romantic references, and more emphasis on texture, immersion, power, role. Terms like “anthro”, "shaft", “designed”, "famous", “texture,” and “toy” dominate, confirming a tone that is simultaneously physical, bold, and gamified. This supports the brand’s identity as unapologetically playful and transgressive.

# %%
# Reloading the file
df_full = pd.read_csv("bad_dragon_top.csv")

# Verifying structure and content
df_full.head(3)
# Out:
#                               Name  Price        Type  \
# 0        Ky'el® the Anthro-Feline    70.0  insertable
# 1      Chance the Flared Stallion®   90.0  insertable
# 2  Flint® the Uncut Studded Dragon   70.0  insertable
#
#                                                                                                                                                                           Short Description  \
# 0  Ky'el® is an anthro feline dildo with a slightly curved shaft featuring small nubs and graspable balls at the base. It’s an excellent toy for beginners and experienced toy users alike.
# 1                                     Chance Flared is the ultimate anthro horse sex toy. Sculpted by hand with a medial ring and bulbous head, you'll want to grab your saddle and hop on.
# 2                                 Flint® is a dildo designed with ridges, studs, and a thick girth. Its simulated foreskin and strong curvature will stimulate you in all the right places.
#
# ...

# %%
# Examining few lines to gain insights on some cathegories
sample_descriptions = df_full['Short Description'].head(10).tolist()
sample_descriptions
# Out:
# ["Ky'el® is an anthro feline dildo with a slightly curved shaft featuring small nubs and graspable balls at the base. It’s an excellent toy for beginners and experienced toy users alike.",
#  "Chance Flared is the ultimate anthro horse sex toy. Sculpted by hand with a medial ring and bulbous head, you'll want to grab your saddle and hop on.",
#  'Flint® is a dildo designed with ridges, studs, and a thick girth. Its simulated foreskin and strong curvature will stimulate you in all the right places.',
#  'Krampus the Satyr™ is a mythological-inspired highly textured dildo with fine details and ridges for a sensation-riddled experience.',
#  "Test out our famous Cumlube and Cumtube with your Lil' Squirt; a uniquely designed lube application accessory.",
#  'Valentino the King of Hearts™ is a highly textured anthro-bear dildo with a tapered head for easier insertion.',
# ...

# %% [markdown]
# > The most recurring words reveal a very different lexicon from that of mainstream sex toys: fewer medical or romantic references, and more emphasis on texture, immersion, power, role.

# %%
# Define a simple function to categorize based on keywords in the name or description
def classify_inspiration(row):
    desc = row['Short Description'].lower()
    name = row['Name'].lower()
    
    if any(word in desc or word in name for word in ['feline', 'stallion', 'bear', 'anthro', 'pony', 'horse']):
        return 'Anthro / Animal'
    elif any(word in desc or word in name for word in ['dragon', 'satyr', 'mystic', 'unicorn', 'myth', 'horn','magical','medieval']):
        return 'Mythological'
    elif any(word in desc or word in name for word in ['tentacle', 'alien', 'tako', 'ridges', 'studs']):
        return 'Tentacle / Alien'
    elif any(word in desc or word in name for word in ['cumtube', 'lube', 'accessory']):
        return 'Accessory / Non-toy'
    else:
        return 'Other / Miscellaneous'

# Apply the classification
df_full['Inspiration Category'] = df_full.apply(classify_inspiration, axis=1)

# Select relevant columns for the summary table
summary_table = df_full[['Name', 'Price', 'Type', 'Inspiration Category', 'Product URL']]
summary_table

# Save the summarized table to CSV
output_path = "bad_dragon_summary_table.csv"
summary_table.to_csv(output_path, index=False)

# Provide the file path to the user
output_path
# Out:
# 'bad_dragon_summary_table.csv'

# %%
# Read the file (after reconnect)
df = pd.read_csv("bad_dragon_summary_table.csv")

# Count the number of products in each category
category_counts = summary_table['Inspiration Category'].value_counts()

# Plot the distribution using matplotlib safely

fig, ax = plt.subplots(figsize=(7,5))
col_cat= []
category_counts.plot(kind='bar', color = 'crimson', ax=ax)
ax.set_title('Distribution of Bad Dragon Products by Inspiration Category')
ax.set_xlabel('Inspiration Category')
ax.set_ylabel('Number of Products')
ax.set_xticklabels(category_counts.index, rotation=45)
ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.savefig('inspiration_category')
plt.show()

# %% [markdown]
# Figure 16 shows that Bad Dragon’s catalog is dominated by mythological and anthro-inspired toys, followed by tentacle/alien designs. This confirms the brand’s core identity as one rooted in fantasy escapism, rather than realism or anatomical reference.

# %% [markdown]
# ###  7.1.4 These toys don’t just break the mold — they reject the mold entirely. They represent:
#
# * A rejection of phallocentrism
# * A queer approach to fantasy and desire
# * A celebration of self-created identities and pleasure narratives
# * A space for erotic imagination, unbound by realism or gender norms
# * Not an imitation of the body, but a liberated symbol of roleplay, fantasy, and agency

# %% [markdown]
# ## 7.2 The Language of Color in Erotic Design: Pink, Purple, Black, and Beyond
#
# ### 7.2.1 Cultural Meanings and Shifting Preferences
#
# Color in sex toys isn’t just about aesthetics — it encodes identity, cultural values, and marketing strategy. Over the past two decades, we've seen a shift from traditional “feminine” pinks to bold purples, moody blacks, and serene neutrals, as brands reimagine who their audience is and what their products should represent.
#
# This evolution mirrors broader cultural shifts around gender, sexuality, and self-expression — moving from rigid binaries to more fluid and empowering visual languages.
#
#
#
# ### 7.2.2 Brand Strategies and Consumer Trends
#
# In a survey featured in the video [*"Which is the color of your favorite sex toy?"*](https://www.youtube.com/watch?v=yvRHyZJbTbk), over 2,000 users revealed their preferred toy colors. Results showed:
#
# - **Pink** slightly outnumbered **purple**
# - **Black** followed closely as the third most popular
# - Other colors (blue, rainbow, metallics, etc.) were far behind
#
# While purple has grown symbolically over the years, this data reminds us that user trends lag behind marketing, many of these toys may have been purchased years ago, gifted, or chosen before current branding trends took hold. Color shifts in consumer products are gradual: what brands champion today may only become dominant in usage data years later.
#
#
# ### 7.2.3 Cultural Meaning of Color
#
# The table below summarizes the symbolic meanings and cultural associations of key colors used in erotic product design:
#
# | Color      | Symbolism & Associations                                                                                   | Communities / Trends                                |
# |------------|-------------------------------------------------------------------------------------------------------------|-----------------------------------------------------|
# | **Purple** | “Sexiest” color; blend of pink & blue; symbolizes fantasy, queerness, royalty, and power                    | Widely adopted; queer-friendly; non-binary appeal   |
# | **Pink**   | Traditional feminine, romantic, “cute”; also seen as infantilizing or stereotyped                           | Declining among LGBTQ+ and collectors               |
# | **Black**  | Elegant, dominant, techy, “serious”; associated with kink, BDSM, and luxury                                  | Popular in premium and fetish lines                 |
# | **Blue**   | Calm, soothing, wellness-oriented; gender-neutral or masculine-coded depending on context                   | Used in wellness & ergonomic brands                 |
# | **Gold / Metallic** | Prestige, wealth, intensity, premium status                                                        | Found in luxury toys and designer collaborations    |
# | **Neutral Pastels** | Soft, gentle, inclusive; often tied to self-care and gender neutrality                             | Used by brands like Dame, Lelo, and Maude           |
# | **Bad Dragon Colors** | Galaxy swirls, neons, fantasy palettes; break realism entirely                                   | Reinforces narrative and character identity         |
#
#
#
# ### 7.2.4 Comparison with Bad Dragon’s Color Palette
#
# Unlike most brands, **Bad Dragon** adopts a vivid, fantasy-driven color system. Their designs include:
#
# - Custom marbling (e.g., red/black, blue/silver)
# - Galaxy swirls and neon gradients
# - Naturalistic “monster” skin tones
# - Optional paint detailing on request
#
# These visual choices serve a narrative function: Bad Dragon toys aren't replicas of the human body — they're imaginative tools for world-building, roleplay, and deviant erotic expression.
#
# As brands move beyond rigid gender coding, **color becomes not just a visual choice, but a declaration of values**: fluidity, empowerment, imagination, and erotic agency.

# %%
# This palette ahs been created in a second momenti in order to facilitate reading comprehension
colors = ['darkred', 'mediumpurple','deepskyblue', 'red', 'lightskyblue',  'fuchsia', 'orange', 'black', 'darkviolet','mediumblue', 'sandybrown','green', 'maroon', 'darkgoldenrod','slategray','purple','gold', 'lightpink']

# Reload the uploaded Excel file
df_colors = pd.read_excel("bad_dragon_top.xlsx")

# Finding the frequency for each color
color_counts = df_colors['Color'].value_counts()

# Plotting a bar chart
plt.figure(figsize=(7,5))
color_counts.plot(kind='bar', color= colors)
plt.title('Main Colors in Bad Dragon Dildos')
plt.xlabel('Color')
plt.ylabel('Number of Products')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()

plt.savefig('main_colors_in_bad_dragon')
plt.show()

# %% [markdown]
# Figure 18 highlights Bad Dragon’s dominant use of intense, non-naturalistic colors. Unlike mainstream brands that stick to soft pinks or purples, Bad Dragon’s palette emphasizes boldness, fantasy, and visual play. These choices reflect the brand’s commitment to escapism and user-defined erotic identity.

# %% [markdown]
# ### 7.2.5 Conclusion: A Palette of Possibilities
#
# The color of a sex toy is never just decorative. It encodes gender assumptions, cultural shifts, and branding strategies. While pink still dominates in legacy consumer data, the rise of purple as a non-binary, luxurious, and queer-associated color signals a deeper evolution in erotic design.
#
# Meanwhile, brands like Bad Dragon actively subvert mainstream palettes with their vibrant, custom, and often multicolored creations—offering not only tools for pleasure but objects of fantasy, art, and identity exploration.
#
# As color choices diversify, sex toys are shedding their clinical or heteronormative appearance and becoming instruments of self-expression, from soft neutrals to cosmic swirls. In choosing a color, the user is often choosing a story, one that reflects not only desire, but identity: the future of erotic design may very well be polychrome.

# %% [markdown]
# ## 7.3 Erotic Cosmetics & Sensory Expansion - From Traditional Remedies to Mainstream Wellness
#
# ###  7.3.1 Westward Transition into Wellness Culture
#
# Sensory creams and arousal serums are no longer niche curiosities. Once relegated to discreet adult shops or marketed with overtly sexualized imagery, these products are now found in pharmacies, herbalist stores, and wellness boutiques—sometimes even without explicit mention of their erotic purpose.
#
# Originating in East Asia, the use of “orgasm creams”, “hot & cold gels”, and herbal aphrodisiacs is long-established. Many of these products leverage botanical ingredients and a tradition of sexual energy enhancement. Today, they are crossing over into Western markets and wellness discourses, often rebranded as tools for mindfulness, intimacy, and sensory connection.
#
# Products often blend:
#
# * Menthol, ginseng, capsaicin, L-arginine
#
# * Natural oils and fragrance components (e.g. ylang-ylang, rose, ginger)
#
# * Formulations that emphasize qi energy, circulation, and holistic arousal
#
# These are sold alongside lubes or herbal tonics—not always erotic, but part of a complete health philosophy.
#
# ### 7.3.2 Strategic Growth of the Sexual Cosmetics Market
#
# In European and North American markets, these creams have found new ground thanks to:
#
# * The rise of wellness marketing
#
# * Retail expansion in pharmacies and e-commerce
#
# * Focus on female pleasure and couple intimacy
#
# Examples:
#
# 🇮🇹 Meafarma, Comodo.it and L’Erboristeria now offer clitoral gels and orgasm boosters in categories like "hygiene & well-being".
#
# These products often highlight natural ingredients, non-invasiveness, and even aroma-therapeutic properties
#
#
# ### 7.3.3 Comparative Positioning
#
# | Aspect       | East Asia	                           | Europe / West                            |
# |--------------|---------------------------------------|------------------------------------------|
# |Main Focus    | Circulation, chi energy, warmth  	   | Arousal, sensitivity, emotional intimacy |
# |Framing	   | Herbal health, aphrodisiac tradition  | Cosmetic + sensual wellness              |
# |Placement	   | Next to lubes or herbal products	   | Separate from lubes, often in “cosmesi”  |
# |Ingredients   |Menthol, ginseng, herbal blends        | Similar actives + marketing flair        |
#
#
# ### 7.3.4 Market Evolution and Strategy
#
# According to a recent [market report](https://www.globenewswire.com/news-release/2025/04/02/3053998/28124/en/Sexual-Wellness-Market-Forecast-to-Reach-62-74-Billion-by-2030-Emerging-Technologies-and-Personalized-Solutions-Set-New-Standards.html), the sexual wellness industry is being reshaped by:
#
# * Informed consumers seeking personalized and health-conscious solutions
#
# * Data-driven innovation: real-time trend tracking, segmentation
#
# * Organic formulations gaining traction
#
# * Omnichannel sales blending pharmacy, online, boutique, and wellness stores
#
# Key brands like **Lovehoney**, **Tenga**, **CalExotics** and **Bijoux Indiscrets** are expanding their cosmetic-style product lines to meet this demand.
#
#
# ### 7.3.5 Commentary: Erotic Care in a Wellness World
#
# What was once taboo is now part of the routine. Arousal creams no longer live only in the nightstand drawer, they're on beauty shelves, beside calming oils and moisturizers. This shift mirrors a broader trend: the normalization and personalization of sexual health, not as indulgence, but as essential self-care.
#
# In this new landscape, the lines between beauty, wellness, and eroticism are not just blurred, they're being rewritten.

# %% [markdown]
# # 8. Industry & Innovation
# ## 8.1 Branding Evolution & Business Identity
#
# In recent decades, the pleasure industry has undergone a profound transformation—not just in terms of products and technology, but in the values and identities behind the brands themselves. Sex toys are no longer just tools for physical stimulation; they have become cultural artifacts, expressions of social change, and often, the personal missions of their founders.
#
# Each company in this landscape emerges from specific needs—mainstream acceptance, feminist rebellion, fantasy exploration, trauma recovery—but evolves into something far more complex. What unites them is how strongly their **brand identities reflect the personal visions, values, and sometimes contradictions of their creators**.
#
# Whether it’s a desire to normalize female pleasure (Sh!, Lora DiCarlo), to challenged legal taboos around contraception and sexuality (Beate Uhse), to bring eroticism into the mainstream (Lovehoney), to celebrate taboo-breaking fantasy (Bad Dragon), or to build reliable, inclusive pleasure products with mass appeal (CalExotics), each company stands as a mirror to both consumer demand and personal philosophy.
#
# In the following comparison, we explore **six key players** through their histories, audiences, innovations, and controversies, revealing how **personal ethos and market opportunity have coalesced into powerful, sometimes fragile, brands**, providing a side-by-side view that represents distinct directions in the evolution of the sex toy industry.
#
# From legacy pioneers to high-tech disruptors, their trajectories reflect not only innovation but also social, political, and personal convictions.

# %%
# Creating a comparative table for the six different brands
data = {
    "Company": [
        "Beate Uhse",
        "Sh!",
        "CalExotics", 
        "Lovehoney", 
        "Bad Dragon", 
        "Lora DiCarlo"
    ],
    "Founded": [
        "1962 (Beate Uhse)",
        "1992 (Kathryn Hoyle and Sophie Walters)",
        "1994 (Susan Colvin)",
        "2002 (Richard Longhurst and Neal Slateford)", 
        "2008 (Varka, Narse, Athus Nadorian and Raith)", 
        "2017 (Lora Haddock)"
    ],
    "Brand Values": [
        "Freedom, sexual wellness, historical feminist legacy",
        "Feminist, trauma-informed, clitoral focus", 
        "Inclusivity, innovation, women-led", 
        "Sexual happiness, mainstream appeal", 
        "Fantasy, custom design, subcultural appeal", 
        "Sex-positive tech, female empowerment (initially)"
    ],
    "Iconic Products": [
        "Contraceptives, erotic media, later sex toys",
        "Non-realistic clitoral and internal toys", 
        "Osé, blended orgasm tech", 
        "Sqweel, Fifty Shades line", 
        "Fantasy dildos (dragon, alien etc.)", 
        "Osé, blended orgasm tech"
    ],
    "Target Audience": [
        "Initially couples and women, now broad", 
        "Women, queer people, trauma survivors", 
        "All genders, all orientations", 
        "Mass market, couples, pop culture fans", 
        "Furries, fantasy fans, adventurous users", 
        "Tech-savvy, feminist-leaning women"
    ],
    "Notable Controversies": [
        "Criticism by feminists for porn business", 
        "None; praised for ethics", 
        "None major reported", 
        "Minimal; mainstream integration", 
        "Niche taste, outsider perception", 
        "Harassment claims, lawsuits, financial collapse"
    ],
    "Innovation Claims": [
        "1st sex shop, over 2,000 lawsuits survived", 
        "Clitoral-first design, Vaginismus Awareness Day", 
        "1st to use feminine colors, waterproof tech, warranties", 
        "1st toy recycling scheme, oral sex simulators", 
        "Community-led designs, semen-like lub", 
        "CES award scandal, biomimetic robotics"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#         Company                                        Founded  \
# 0    Beate Uhse                              1962 (Beate Uhse)
# 1           Sh!        1992 (Kathryn Hoyle and Sophie Walters)
# 2    CalExotics                            1994 (Susan Colvin)
# 3     Lovehoney    2002 (Richard Longhurst and Neal Slateford)
# 4    Bad Dragon  2008 (Varka, Narse, Athus Nadorian and Raith)
# 5  Lora DiCarlo                            2017 (Lora Haddock)
#
#                                            Brand Values  \
# 0  Freedom, sexual wellness, historical feminist legacy
# 1             Feminist, trauma-informed, clitoral focus
# 2                    Inclusivity, innovation, women-led
# 3                   Sexual happiness, mainstream appeal
# 4            Fantasy, custom design, subcultural appeal
# 5     Sex-positive tech, female empowerment (initially)
#
#                                 Iconic Products  \
# 0  Contraceptives, erotic media, later sex toys
# ...

# %% [markdown]
# ## 8.2 Materials, Sustainability, Inclusivity
#
# In contemporary sex toy manufacturing, **material selection and ethical engineering** have become key differentiators in a competitive and increasingly regulated market. The shift from porous, potentially hazardous materials to **medical-grade silicone, ABS plastic, and non-toxic elastomers** has elevated both consumer safety standards and product longevity.
#
# **CalExotics** pioneered several innovations in this domain, introducing **100% premium silicone devices** and becoming one of the first manufacturers to standardize **waterproofing and product warranties**—elements now considered industry benchmarks. Similarly, **Bad Dragon**’s artisanal production model relies on hand-poured silicone formulations with customizable firmness, color, and sizing. This model not only meets stringent quality requirements but also supports niche consumers with non-normative preferences and anatomical needs.
#
# **Sustainability** efforts have emerged in tandem with material innovation. In 2007, **Lovehoney** launched the first formal **sex toy recycling program** (Rabbit Amnesty), addressing a critical gap in end-of-life product management. **CalExotics** followed with advancements including **solar-powered vibrators** and **wireless chargers with built-in UV sanitization**, integrating eco-conscious design with hygienic functionality.
#
# On the axis of **inclusivity**, brand strategies have moved beyond gendered marketing to embrace broader notions of sexual identity, health status, and trauma recovery. **Sh!** has positioned itself explicitly within a trauma-informed and feminist framework, designing products that avoid anatomical mimicry and supporting initiatives such as **Vaginismus Awareness Day** and partnerships with **Macmillan Cancer Support**. **CalExotics** established the first **all-women product development team**, and **Bad Dragon**, while rooted in fantasy subcultures, enables expression for users across gender identities and kinks often marginalized by the mainstream market.
#
# Together, these developments reflect a significant evolution: sex toys are no longer neutral objects, but **engineered instruments of inclusive, safe, and sustainable pleasure**.
#
#
# ### 8.2.1 Regulatory Considerations and CE Marking
#
# In the European Union, sex toys fall under two regulatory regimes:
#
# * **General consumer products**, governed by Directive 2001/95/EC, **do not require CE marking**. In fact, displaying the CE mark on these products is **illegal** and misleading.
#
# * **Electrical or electronic products** (e.g., vibrators, app-connected devices) **must display the CE mark**, ensuring compliance with relevant EU directives (e.g., Low Voltage Directive, EMC Directive).
#
# Despite their intimate use and mucosal contact, **non-electric sex toys lack sector-specific legislation**. In 2023, MEP Sara Cerdas requested EU-wide norms to address this gap, citing consumer safety concerns. The European Commission declined, stating:
#
# > “The Commission does not intend to propose sectoral legislation for sex toys in the near future.”
# > Nevertheless, under the current framework, **all sex toys must meet general product safety standards**, with manufacturers expected to provide adequate **risk assessments, usage instructions, and hygiene guidelines**.
#
# As a result, **compliance and consumer trust often depend on voluntary best practices**—especially from premium brands that integrate safety, sustainability, and ethical transparency as core brand values.
#
# The table below summarizes when CE marking is required for various categories of sex toys and related products under EU law, helping clarify safety and compliance obligations for manufacturers and retailers.
#
# | Product Type                         | CE Mark Required? | Based on EU Law                            | Notes                                                                 |
# |-------------------------------------|-------------------|--------------------------------------------|-----------------------------------------------------------------------|
# | **Electric/electronic sex toys**    | Yes            | Low Voltage Directive / EMC Directive      | Must comply with safety, electromagnetic compatibility, and sometimes RoHS (for electronics). |
# | **Battery-operated vibrators**      | Yes            | As above                                   | Includes toys with internal motors, USB charging, remote control.     |
# | **App-connected sex tech**          | Yes            | RED Directive (if wireless)                | Data privacy may also be relevant (GDPR if collecting personal data). |
# | **Non-electric/manual toys**        | No             | General Product Safety Directive 2001/95/EC| CE mark **must not** be shown. Products must still meet safety standards. |
# | **Lubricants and gels**             | Usually No     | May fall under cosmetics or medical devices| Check classification carefully: some may require separate conformity steps. |
#
# >  *Reminder:* Even without CE requirements, **risk analysis, toxicity testing, and user information are essential for legal compliance and consumer trust.**
#
#
# ## 8.3 The Role of Data and Personalization
#
# The sex tech industry is rapidly evolving from static product design to **data-driven, personalized experiences**. Smart vibrators, app-connected toys, and customizable platforms have introduced a new paradigm: one where intimacy and algorithms intersect.
#
# Several companies now offer devices that **learn from user behavior** storing vibration preferences, customizing patterns, or adapting stimulation based on biometric feedback. Others, like **Bad Dragon**, rely on physical personalization, allowing buyers to choose dimensions, firmness, and even ejaculation simulators. In all cases, the trend is clear: **users want control, and brands compete on adaptability**.
#
# Yet, **with innovation comes complexity**. The growing use of data—from app settings to sexual response logs—raises significant concerns. Who owns this data? How is it stored, and for how long? What happens if it's breached?
#
# These questions are far from hypothetical. In 2016, **researchers exposed major vulnerabilities in Bluetooth-enabled sex toys**, revealing that user commands and intimate metadata could be intercepted. The most notable case involved We-Vibe: the company collected usage data (temperature, vibration intensity, time) without clear consent and was later ordered to pay damages in a class-action lawsuit.
#
# **Lora DiCarlo**, with its data-connected, robotics-driven devices, also operated in this gray zone. Despite its sex-positive branding, the company gathered significant usage data without clear public documentation on storage, anonymization, or third-party access. When the company collapsed in 2022, it left unanswered questions—not just about unpaid wages and lawsuits, but about **what happened to the data collected from thousands of users**.
#
# Currently, the EU lacks specific regulation for sex tech privacy. While GDPR applies in theory, most users are unaware that their most intimate interactions may be tracked or stored. As sex toys become more connected, **privacy and cybersecurity are no longer side issues**, they are essential components of product safety and user trust.
#
# In the near future, personalization may define user experience but **transparency and accountability will define brand survival**.

# %% [markdown]
# ## 8.4 Cybersecurity, Consent and Data Ownership
#
# As sex toys evolve into app-connected and data-driven devices, the industry faces not only technological challenges but also pressing questions about **privacy, security, and informed consent**.
#
# One of the most prominent cases occurred in 2016, when Canadian manufacturer **Standard Innovation** faced a class-action lawsuit over its We-Vibe vibrator. The device’s companion app, We-Connect, collected detailed user data—including temperature, vibration settings, and session duration **without explicit user consent**. The company ultimately agreed to a $3.75 million settlement and was required to cease data collection and destroy previously gathered information.
#
# Similarly, **Lora DiCarlo**, celebrated for its high-tech, biomimetic products like Osé, gathered anatomical and usage data in the name of innovation. While the company promoted a message of sex-positivity and empowerment, there was **little transparency regarding how user data was stored, secured, or shared**. When the company abruptly collapsed in 2022, it left behind not only unpaid wages and legal disputes, but also unanswered questions about the fate of sensitive user data collected through its devices.
#
# Although the **General Data Protection Regulation (GDPR)** technically applies to all personal data processed within the EU, there is currently **no sector-specific legislation for sex tech**. In 2023, MEP Sara Cerdas urged the European Commission to adopt dedicated regulation for sex toys, particularly due to the risks posed by products that come into direct contact with mucous membranes. The Commission declined, stating that existing product safety rules were sufficient.
#
# Yet, the risks are far from theoretical. Research has shown that **Bluetooth-enabled sex toys can be hacked**, potentially exposing intimate commands or even allowing remote control by unauthorized users. As personalization becomes the norm, **the boundary between intimacy and surveillance grows thinner**.
#
# For brands operating in this space, cybersecurity and data ethics are no longer optional add-ons—they are **core responsibilities**. In the absence of dedicated legislation, **consumer trust will depend on voluntary best practices, transparent policies, and proactive risk mitigation**.

# %% [markdown]
# ## 8.5 Companies and Product Portfolios
#
# The previous table provided a comparative overview of six prominent companies in the sex toy industry. To further illustrate their distinct identities, the following visual gallery highlights each brand's approach to product design, packaging, and marketing.
#
# <table>
#   <tr>
#     <td>
#       <img src="images/Beate_Uhse_Hamburg.jpg" width="220"><br>
#       <sub><b>Beate Uhse, Hamburg, nowadays</b><br>
#       A traditional brand showcase. Much has been achieved.</sub>
#     </td>
#     <td>
#       <img src="images/sh-women-s-store-sh-dildo-duchess-dildo-72797319168386_480x.jpg" width="220"><br>
#       <sub><b>Sh!, Silicone Dildos Handmade by Women</b><br>
#       "They are not penises."</sub>
#     </td>
#     <td>
#       <img src="images/Dual_Rider_Calexotics.jpg" width="220"><br>
#       <sub><b>Calexotics, Bestseller number 1</b><br>
#       "Own your pleasure."</sub>
#     </td>
#   </tr>
#   <tr>
#     <td>
#       <img src="images/86360_a48513_purple_000.jpg" width="220"><br>
#       <sub><b>Lovehoney</b><br>
#       Bold purple branding, tech appeal, and playful inclusivity.</sub>
#     </td>
#     <td>
#       <img src="images/6736e27e-8219-46c2-9462-43fe199f0b6e.jpg" width="220"><br>
#       <sub><b>Bad Dragon: Meet Ika® the Tentacle</b><br>
#       An award-winning fantasy-themed dildo.</sub>
#     </td>
#     <td>
#       <img src="images/a_new_esthetic_Osè_2.jpg"  width="220"><br>
#       <sub><b>Lora DiCarlo's technology and design</b><br>
#       aimed at empowering women.</sub>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# Across all case studies and technological shifts explored in this chapter, one message is clear: **sex toys** are no longer marginal or purely functional items. They are **political**, **aesthetic**, and **technological artefacts** shaped by regulatory gaps, social debates, and the aspirations of both users and makers.
#
# From feminist led ethics to gamified fantasy, from silicone sustainability to algorithmic personalization, the sex toy industry now moves in multiple, sometimes contradictory directions. The convergence of values and capital, of empowerment and risk, of inclusion and surveillance, defines the innovative, fragile, and fascinating nature of this evolving field.

# %% [markdown]
# # 9 From Tools to Symbols – A Data-Driven Perspective
#
# Chapter 8 explored how brands shape the sex toy landscape. Now, in Chapter 9, we turn the lens around to look not just at companies, but at people.
#
# What do sales data reveal about real desires? What do usage patterns tell us about agency, aging, relationships, and freedom?
#
# Here, sex toys become more than just products, they become symbols of autonomy, compatibility, and change.
#
# Sex is about enjoyment, not just “the hole or the pole,” but the human being behind it.
# Sales data from three major companies (Sh! – UK, Beate Uhse – Germany, and CalExotics – USA) suggest that sexual satisfaction and toy usage are driven less by mimicry of bodies and more by exploration of sensation, anatomy, and agency.
#
# This shift in demand reflects a deeper consumer trend: people aren’t buying replicas, they’re buying tools for self-discovery and relationship enrichment. These symbolic choices have pricing consequences too. The most appreciated toys, across all categories, often fall into higher price tiers, indicating a **growing link between emotional resonance, brand storytelling, and perceived product value**.
#
# Indeed, across all sexual orientations, women consistently buy more **penetrative sex toys** than non-penetrative ones.
# It’s clear from both qualitative studies and consumer behavior that dildos and vibrators are not about replicating a man's penis, they’re about recreating the **sensation of penetration**.
#
# Lesbians, for example, aren’t attracted to men, but may enjoy penetration: they share the same anatomy as heterosexual women, and their preferences reflect that. What this teaches brands is critical: **design isn’t about gender**; it’s about **function, sensation, and agency**.
#
#
#
# ## Women’s Sexuality Evolves with Age
#
# Multiple studies confirm that women’s sexual needs, curiosity, and confidence tend to **increase with age**, not decline.
#
# - Younger women may buy toys out of curiosity or experimentation.
# - Women in their 30s–40s often seek quality, compatibility with partners, and better self-knowledge.
# - Women 50+ increasingly value control over pleasure, independence, and intimacy on their own terms.
#
# **Sexual agency matures and toy choices mature with it.**
# This offers businesses a powerful insight: the idea that sex toys are “for young women” is not only outdated: it’s a missed market opportunity.
#
#
#
# ## Not Just Solo: Couple Satisfaction
#
# Toys are not just tools for solo pleasure, they’re bridges in relationships.
# Numerous studies have shown that **couples who use toys together** report higher satisfaction levels, improved communication, and better sexual compatibility.
#
# This is especially true with toys that enable shared control, playful dynamics, or remote intimacy.
# **CalExotics**, notably, positions many of its products for couple use with app control, dual stimulation, and wearable tech. Their catalog reflects a strategic move toward shared pleasure as a cultural and commercial value.
#
# For brands, this signals a growth area: products designed to enhance intimacy, not just individual release, are gaining traction and loyalty.
#
#
#
# ## What This Data Tells Us
#
# > “Sexual pleasure comes in different shapes, forms, and colors. Our fantasies aren’t bound by gender or labels, but shaped by experience, freedom, and choice.”
#
# - Penetration is not about the penis.
# - Toys are not about gender roles, they’re about physical feedback and personal autonomy.
# - The idea that “penetration = submission” is reductive.
#   For many, the power lies in **giving consent**, in **trusting your own reactions**, in exploring pleasure without judgment.
#
# For business leaders and designers, the takeaway is clear: **users reward brands that embrace diversity, agency, and emotional intelligence**. Success lies not in reproducing anatomical clichés, but in understanding the lived experience of desire from the beginner’s curiosity to the seasoned user's self-assurance.
#
# Ultimately, the shift from tool to symbol tells a bigger story, one where **sex is not a performance, but a process**. Not a role to play, but **a right to claim**.
#
# As the industry evolves, one trend remains constant: the more diverse our tools become, the more diverse, and liberated, our stories of pleasure can be.
#
# What we learn from sex toys is not just how people experience pleasure, but how they reclaim it.
#
# In the stories behind these objects, their use, their rejection, their reinvention,  we find echoes of trauma, healing, identity formation, and social permission.
# Pleasure becomes not just an act, but a language: to communicate with oneself, with others, or with the unspoken histories of shame and silence.
#
# From entry-level bullet vibes to award-winning blended-orgasm tech, sex toys are no longer neutral.
# They are coded with meanings of freedom, queerness, care, imagination, and rebellion.
#
# Even failure matters: Lora DiCarlo’s collapse wasn’t just a startup downfall. It was a moment where ambition, tech, feminism, and unresolved power dynamics clashed.
# And that too is part of the story.
#
# Today, sex toys live in algorithms, in lawsuits, in memory foam and fantasy worlds. They are sold in supermarkets and crowdfunded online.
# They educate, stimulate, provoke, and evolve.
#
# **Ultimately, this project shows us not only what we touch, but what touches us in return.**
#
# A sex toy is a tool.
# But also a symptom.
# A question.
# A mirror.

# %% [markdown]
# # 10. Limitations and Future Research Directions.
#
# ## Scope and Generalizability
#
# While this analysis offers a compelling contrast between bestselling and most loved sex toys, it draws from a limited number of platforms, few, but significant. As such, several limitations apply:
#
# - **Lack of demographic data**: Age, gender, and sexual orientation of customers remain unknown.
# - **No real-time sales metrics**: Product popularity is inferred from site categorizations (e.g., “Bestseller”), not transparent sales figures.
# - **Geographic focus**: The German site of Beate Uhse, the US-based CalExotics, and the UK’s Sh! provide valuable contrast, but may not reflect global or multilingual markets.
#
# Despite these constraints, the current data paints a valuable picture of how consumer behavior, product design, and cultural attitudes intersect in the sex toy industry and points to meaningful patterns worth deeper exploration.
#
#
#
# ## 10.2 Suggestions for Further Study
#
# Future research could expand this analysis in several directions, enriching both academic and commercial perspectives:
#
#
# ### Aging and Sexuality
#
# As global life expectancy rises, older adults represent a growing yet underserved segment of the sex toy market. Future research should explore how design, communication, and distribution can better meet their needs — particularly given the overlap with mobility, dexterity, and sensory challenges. Visibility, accessibility, and education remain key gaps.
#
# ### Inclusive Design & Representation
#
# According to the World Health Organization, nearly **37.5% of the world’s population** lives with a disability. The sex toy industry is still in the early stages of addressing this reality.
#
# <table>
#   <tr>
#     <td>
#       <img src="images\Lovehoney_ad.jpg" width="400"><br>
#       <sub><b>"Promotional image from Lovehoney’s inclusive campaign</b><br>
#       spotlighting sexual confidence and connection beyond ableist norms."</sub>
#     </td>
#    </tr>
# </table>
#
# Further work could examine:
#
#     - Toys adapted for limited dexterity or mobility
#     - Inclusive advertising across ability, gender identity, and body size
#     - Narratives from users with disabilities and their lived experiencess
#
# * **Emerging technologies**: Investigate the growing market of **audio-responsive toys**, **AI-powered devices**, and **VR-integrated experiences**. These products are redefining intimacy and may reshape consumer expectations in profound ways.
#
# * **Cultural representation**: Explore how branding, language, and design aesthetics vary across global markets, especially in non-Western regions, LGBTQ+ communities, neurodivergent audiences and how erotic tools are positioned in relation to local taboos, religions, or social codes
#
# * **User-generated data**: Incorporate product reviews, forum discussions, or anonymized usage patterns to better understand emotional attachment, satisfaction, and unmet needs.
#
# * **Sustainability**: Analyze how ecological concerns (from rechargeable batteries to recyclable packaging) are influencing both design choices and consumer loyalty. This could become a new form of brand differentiation.
#
# * **Retail vs. direct-to-consumer trends**:
#
# Compare legacy retailers to indie or DTC brands to evaluate who sets the trends and who follows them.
#
#     - Who drives innovation vs. who replicates it
#     - How authenticity and niche identity compete with broad-market reach
#     - What role e-commerce plays in reshaping stigma, access, and choice
#
#
# Taken together, these paths suggest that the study of sex tech, when blended with cultural theory, product design, market analysis, and human psychology, has only just begun.

# %% [markdown]
# # 11 Source URLs and Citations
#
# [Do Sex Toys Make Me Satisfied?](https://doi.org/10.1080/00224499.2024.2304575)
#
# [Google Trends Study – Sexual Medicine Journal](https://academic.oup.com/smoa/article/12/5/qfae072/7908787)
#
# [Straits Research – Europe Sex Toys Market Report](https://straitsresearch.com/report/europe-sex-toys-market)
#
# [Grand View Research – Global Sex Toys Market](https://www.grandviewresearch.com/industry-analysis/sex-toys-market)
#
# [TechySex / Markets Insider – European Interest in Sex Toys](https://markets.businessinsider.com/news/stocks/the-u-s-lags-behind-when-it-comes-to-exploring-sex-toys-online-but-sweden-is-leading-the-way-1031369063)
#
# [‘A lazy solution’: Etsy sellers say ban on sex toys is a betrayal](https://www.theguardian.com/business/article/2024/jul/11/etsy-sellers-ban-sex-toys-betrayal)
#
# [How Purple Became The Sexiest Color](https://www.nylon.com/articles/why-purple-sexiest-color)
#
# [Vibrator Color Can Make A Difference: What Color Are You?](https://www.sohimi.com/blogs/tips/vibrator-color-can-make-a-difference-what-color-are-you?srsltid=AfmBOorzWHOvmJCm0QZYQTYQiDf4NbwO08cVCRk1k46GtRoFbuqMjEaL)
#
# [For Sex Toys, Purple Is the New Pink](https://www.getmegiddy.com/sex-toys-purple)
#
# [Ky Hoyle Speaks About Founding the U.K.’s First Women’s Sex Shop](https://www.thebody.com/article/ky-hoyle-founder-united-kingdom-first-womens-sex-shop)
#
# [This Londoner founded Europe's first women-focused sex shop](https://www.timeout.com/london/things-to-do/this-londoner-founded-europes-first-women-focused-sex-shop)
#
# [NONCHALANT Interview with Ky Hoyle, Founder of Sex Shop Sh!](https://www.nonchalantmagazine.com/sex-shop-talk-in-conversation-with-ky-hoyle-founder-of-sh/)
#
# [Vice, an interview with Jan “Varka” Mulders](https://www.vice.com/it/article/a-letto-con-il-mostro/)
#
# [Buzzkill](https://oregonbusiness.com/19737-buzzkill-lora-dicarlo-postmortem-sexual-harassment-patent-lawsuit/)
#
# [Sexual Wellness Company Lora DiCarlo Quietly Ends Operations](https://www.beautyindependent.com/sexual-wellness-company-lora-dicarlo-quietly-ends-operations/)
#
# [German Sex-Toy Maker Awarded 2.2M Default Judgment Against Lora DiCarlo](https://oregonbusiness.com/german-sex-toy-maker-awarded-2-2m-default-judgment-against-lora-dicarlo/)
#
# [Marcatura CE sex toys](https://marcaturace.net/le-apparecchiature-elettriche/marcatura-ce-sex-toys-giocattoli-sessuali#:~:text=La%20marcatura%20CE%20e%2Fo,se%20pochi%20ne%20parlano%20liberamente.)
#
# [Sex toys, dal Parlamento l’appello a regole UE. La Commissione: “Nessuna proposta nel prossimo futuro”](https://www.eunews.it/2024/02/12/sex-toys-da-parlamento-appello-regole-ue/)
#
# [Tech company accused of collecting details of how customers use sex toys](https://www.theguardian.com/us-news/2016/sep/14/wevibe-sex-toy-data-collection-chicago-lawsuit?utm_source=chatgpt.com)
#
# [Internet-Connected Sex Toy Maker Settles Privacy Lawsuit](https://www.bankinfosecurity.com/internet-connected-sex-toy-maker-settles-privacy-lawsuit-a-9774?utm_source=chatgpt.com)
#
# [The Next Security Risk May Be Your Vibrator](https://www.wired.com/story/the-next-security-risk-may-be-your-vibrator/)
#
# [Even sex toys can be connected to the internet – and hacked](https://phys.org/news/2017-04-sex-toys-internet-hacked.html)
#
# [How a Sex-Tech Company CEO Gets It Done](https://www.thecut.com/2021/04/how-lora-haddock-dicarlo-gets-it-done.html?utm_source=chatgpt.com)
#
# [Women of the Week: an interview with Lora DiCarlo](https://www.databirdjournal.com/posts/lora-dicarlo?utm_source=chatgpt.com)
#
# [Vibrator users will receive 10,000 each after company tracked their sexual activity](https://www.marketwatch.com/story/bad-vibrations-your-sex-toy-may-be-collecting-information-about-you-2016-09-20)
#
# [Maker of smart vibrator sued for snooping on customers’ use](https://news.sophos.com/en-us/2016/09/20/maker-of-smart-vibrator-sued-for-snooping-on-customers-use/)
#
# [Tech company accused of collecting details of how customers use sex toys](https://www.theguardian.com/us-news/2016/sep/14/wevibe-sex-toy-data-collection-chicago-lawsuit)
#
# [Someone made a smart vibrator, so of course it got hacked](https://www.theguardian.com/technology/2016/aug/10/vibrator-phone-app-we-vibe-4-plus-bluetooth-hack)
#
# [Tech Firms Warn of Growing Cyber Risks, From Medical Devices to Sex Toys](https://www.carriermanagement.com/news/2016/03/17/152218.htm)
#
# [Here’s a new thing for masturbators to worry about](https://nypost.com/2016/03/17/is-that-a-hacked-sex-toy-in-your-pocket-or-are-you-just-happy-to-see-me/)
#
# [Lora DiCarlo: Our Commitment to Your Privacy](https://development.optikal.com/ldc/privacy-policy/)
#
# [Cara Delevingne Joins Sextech Startup Lora DiCarlo as Co-Owner & Creative Advisor
# By Femtech Insider Career, Sextech November 26, 2020 Share](https://femtechinsider.com/cara-delevigne-joins-sextech-startup-lora-dicarlo/)
#
# [Lora DiCarlo says CES wrongly rescinded award for micro-robotic sex toy](https://venturebeat.com/business/lora-dicarlo-says-ces-wrongly-rescinded-award-for-micro-robotic-sex-toy/)
#
# [Smashing stereotypes: Lovehoney partners with disability start-up Handi](https://insideretail.com.au/business/customer/smashing-stereotypes-lovehoney-announces-partnership-with-disability-start-up-handi-202012)
#
# [Beate Uhse](https://www.beate-uhse.com/)
#
# [CalExotics](https://calexotics.com/)
#
# [Sh!](https://sh-womenstore.com/pages/sh-womens-what-we-stand)
#
# [Bad Dragon](https://bad-dragon.com/)
#
# [Lovehoney](https://www.lovehoney.co.uk/)
